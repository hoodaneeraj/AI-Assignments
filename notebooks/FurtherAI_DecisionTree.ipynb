# %% [markdown]
# Code to accompany Machine Learning Recipes #8. We'll write a Decision Tree Classifier, in pure Python. Below each of the methods, I've written a little demo to help explain what it does.

# %%
import pandas as pd
import numpy as np
from collections import Counter
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Decision Tree Implementation
# * The Tree takes the whole Dataset as an input
# * DataSet must be a list of list with each list in the dataset representing a row
# * The implementation presumes **the last column represents label**

# %% [markdown]
# ##### Helper Functions

# %%
### Method to find unique values in a Column
def find_unique_feature_values(rows, col):
    return set([row[col] for row in rows])

# %%
### Count the number of each label in the data
### The method assumes the last column to be the label in the dataset
def label_count(rows):
    counts = Counter((np.array(rows))[:,-1]) # a dictionary of label -> count.
    return counts

# %%
### Check if a value is numeric value.
def is_numeric(value):
    return isinstance(value, int) or isinstance(value, float)

# %% [markdown]
# ##### Class to hold the data partition criteria

# %%
##This class  is used to partition the dataset.it records the column index and the value used for partition criteria
##records a 'column number' e.g., 0 for 'Outlook' and a value e.g. 'Sunny'
##The 'compare' method is used to compares the passed feature value with the partition citeria value 
    
class partition_criteria:
    
    def __init__(self, column, value):
        self.col = column
        self.value = value

    def compare(self, row):
        val = row[self.col]
        if is_numeric(val):
            return val >= self.value
        else:
            return val == self.value

    def __repr__(self):
        # Helper function to print the criteria
        condition = "=="
        if is_numeric(self.value):
            condition = ">="
        return "%s %s %s?" % (header[self.col], condition, str(self.value))

# %% [markdown]
# ##### Splitter Function : Splits and retuns lists of  passed and failed data

# %%
##get_split() : Splits the dataset ,  
##for each row in the dataset checks if it matches the partition criteria. 
##if it matches add to 'success' rows, otherwise, add it to 'failed' rows.

def get_split(rows, criteria):
    success, failed = [], []
    for row in rows:
        if criteria.compare(row):
            success.append(row)
        else:
            failed.append(row)
    return success, failed

# %% [markdown]
# ##### Function to calculate Gini Impurity

# %%
##Calculate the gini impurity as : 
## gini_impurity = 1 - sum(probability_of_each_class**2)
def gini_impurity(rows):
    counts = label_count(rows)
    impurity = 1
    for cls in counts:
        probability = counts[cls] / len(rows)
        impurity -= probability**2
    return impurity

# %% [markdown]
# ##### Function to calculate Information Gain

# %%
### Information Gain is defined as:
### IG = Starting_impurity - sum(Weighted_impurity_of_each_label for a feature) 

def info_gain(left, right, current_uncertainty):
    p = float(len(right)) / (len(left) + len(right))
    return current_uncertainty - p * gini_impurity(right) - (1 - p) * gini_impurity(left)

# %% [markdown]
# ##### Function to find the best split : Returns the spilt Criteri and best IG value

# %%
## Find the best criteria to split by iterating over every feature / value
## and calculating the information gain."""

def find_best_split(rows):
    
    best_IG = 0  # record the best information gain
    best_criteria = None  # record the feature / value that produced it
    
    current_uncertainty = gini_impurity(rows)
    
    # n_features = number of columns, excluding the label column which we presume is the last column
    n_features = len(rows[0])-1   
    
    for col in range(n_features):  # for each feature
        
        #get unique values in the column
        values = set([row[col] for row in rows])

        # for each value
        for val in values:  

            # find the best criteria to split
            criteria = partition_criteria(col, val)

            # split the dataset on criteria
            pass_rows, fail_rows = get_split(rows, criteria)

            # if pass_rows or fail_rows ==0 skip this split as it doesn't divide the dataset
            if len(pass_rows) == 0 or len(fail_rows) == 0:
                continue

            # Calculate the information gain from this split
            gain = info_gain(pass_rows, fail_rows, current_uncertainty)

            # if the gain >= best_IG set best_IG and best_criteria.
            if gain >= best_IG:
                best_IG, best_criteria = gain, criteria

    return best_IG, best_criteria

# %% [markdown]
# ##### This class represents the Leaf Node in a Tree

# %%
##Leaf class just holds the labels/predictions in a dictionary {'Yes', 'No'}
class Leaf_Node:
    def __init__(self, rows):
        self.predictions = dict(label_count(rows))

# %% [markdown]
# ##### This class represents a non-Leaf Node or a Decison Nede it holds :
# * Split Criteria for the Node
# * The passed branch (passes criteria)
# * The failed branch (fails criteria)

# %%
## This class holds a reference to the criteria, and the two child nodes.
class Decision_Node:
    def __init__(self,
                 criteria,
                 passed_branch,
                 failed_branch):
        self.criteria = criteria
        self.passed_branch = passed_branch
        self.failed_branch = failed_branch

# %% [markdown]
# ##### Builds the Tree recursively

# %%
## This method Builds the tree recursively.

def build_tree(rows):
    
    # Partitioning the dataset on each of the unique attribute,
    # calculate the information gain,
    # and return the criteria that produces the highest gain.
    #print(f"buid_tree = {rows}")
    info_gain, criteria = find_best_split(rows)
    #print(f"Node Split criteria : {criteria}")
    
    # Base case: no further info gain
    # There are no more criterias for comparison, return a leaf node
    if info_gain == 0:
        return Leaf_Node(rows)

    # Found useful feature/value to split the data
    passed_rows, failed_rows = get_split(rows, criteria)

    # Recursively build the branch that passed the criteria.
    successful_branch = build_tree(passed_rows)

    # Recursively build the branch that failed the criteria.
    failed_branch = build_tree(failed_rows)

    # Return a Decision node.
    # This Node represents :
      ### The  feature / value to check for at this point,
      ### Branches to follow depending on the answer.
    return Decision_Node(criteria, successful_branch, failed_branch)

# %% [markdown]
# ##### Prints the Tree Recursively : Prints the Criteria for the Node and at the leaf the label and Probability

# %%
def print_tree(node, spacing=""):
        
    if isinstance(node, Leaf_Node):
        prob = {}
        total = sum(node.predictions.values())
        for key in node.predictions.keys():
            prob[key] = str((node.predictions[key]/total *100)) + '%'
        print (spacing + f"Decision : {prob}")
        return

    # Print the criteria at the node
    print (spacing + str(node.criteria))

    # Call recursively on the passed branch
    print (spacing + '--> True:')
    print_tree(node.passed_branch, spacing + "  ")

    # Call recursively on the failed branch
    print (spacing + '--> False:')
    print_tree(node.failed_branch, spacing + "  ")

# %% [markdown]
# ##### Recursive Classification Function : Takes a row and decides the Label for it.

# %%
## Method to run the classification on Data recursively
def classify(row, node):
    # If the node of type Leaf, we have a decision on class
    if isinstance(node, Leaf_Node):
        return node.predictions

    # Now do the classification of two branches passed-branch / failed-branch.
    # Compare the feature / value stored in the node, to the record we're considering.
    if node.criteria.compare(row):
        return classify(row, node.passed_branch)
    else:
        return classify(row, node.failed_branch)

# %% [markdown]
# #### Print the Leaf Node

# %%
## Print the leaf node with probability as %
def print_leaf(counts):
    total = sum(counts.values()) * 1.0
    probs = {}
    for lbl in counts.keys():
        probs[lbl] = str(int(counts[lbl] / total * 100)) + "%"
    return probs

# %% [markdown]
# #### Calculate the accuracy of the DT

# %%
def accuracy(data):
    accuracy_score = 0
    total =0
    for row in testing_data:
        counts = classify(row, my_tree)
        total += sum(counts.values()) * 1.0
        if row[-1] in counts:
            accuracy_score += counts[row[-1]]
    return accuracy_score/total * 100

# %% [markdown]
# ## Test  the Decision Tree for Weather Data

# %%
### Read the csv using Pandas and split into training and testing Data

weather_data = "seattle-weather.csv"
weatherData = pd.read_csv(weather_data)
weatherData = weatherData.drop(["date"] , axis=1,inplace=False)
header = list(weatherData.columns.values)
weatherData = weatherData.values.tolist()
training_data, testing_data = train_test_split(weatherData, test_size=.40, random_state=1)

# %%
weatherData
# Out:
# [[0.0, 12.8, 5.0, 4.7, 'drizzle'],
#  [10.9, 10.6, 2.8, 4.5, 'rain'],
#  [0.8, 11.7, 7.2, 2.3, 'rain'],
#  [20.3, 12.2, 5.6, 4.7, 'rain'],
#  [1.3, 8.9, 2.8, 6.1, 'rain'],
#  [2.5, 4.4, 2.2, 2.2, 'rain'],
#  [0.0, 7.2, 2.8, 2.3, 'rain'],
#  [0.0, 10.0, 2.8, 2.0, 'sun'],
#  [4.3, 9.4, 5.0, 3.4, 'rain'],
#  [1.0, 6.1, 0.6, 3.4, 'rain'],
#  [0.0, 6.1, -1.1, 5.1, 'sun'],
#  [0.0, 6.1, -1.7, 1.9, 'sun'],
#  [0.0, 5.0, -2.8, 1.3, 'sun'],
#  [4.1, 4.4, 0.6, 5.3, 'snow'],
#  [5.3, 1.1, -3.3, 3.2, 'snow'],
#  [2.5, 1.7, -2.8, 5.0, 'snow'],
#  [8.1, 3.3, 0.0, 5.6, 'snow'],
#  [19.8, 0.0, -2.8, 5.0, 'snow'],
#  [15.2, -1.1, -2.8, 1.6, 'snow'],
#  [13.5, 7.2, -1.1, 2.3, 'snow'],
#  [3.0, 8.3, 3.3, 8.2, 'rain'],
#  [6.1, 6.7, 2.2, 4.8, 'rain'],
#  [0.0, 8.3, 1.1, 3.6, 'rain'],
#  [8.6, 10.0, 2.2, 5.1, 'rain'],
#  [8.1, 8.9, 4.4, 5.4, 'rain'],
#  [4.8, 8.9, 1.1, 4.8, 'rain'],
#  [0.0, 6.7, -2.2, 1.4, 'drizzle'],
#  [0.0, 6.7, 0.6, 2.2, 'rain'],
#  [27.7, 9.4, 3.9, 4.5, 'rain'],
#  [3.6, 8.3, 6.1, 5.1, 'rain'],
#  [1.8, 9.4, 6.1, 3.9, 'rain'],
#  [13.5, 8.9, 3.3, 2.7, 'rain'],
#  [0.0, 8.3, 1.7, 2.6, 'sun'],
#  [0.0, 14.4, 2.2, 5.3, 'sun'],
#  [0.0, 15.6, 5.0, 4.3, 'sun'],
#  [0.0, 13.9, 1.7, 2.9, 'sun'],
#  [0.0, 16.1, 1.7, 5.0, 'sun'],
#  [0.3, 15.6, 7.8, 5.3, 'rain'],
#  [2.8, 10.0, 5.0, 2.7, 'rain'],
#  [2.5, 11.1, 7.8, 2.4, 'rain'],
#  [2.5, 12.8, 6.7, 3.0, 'rain'],
#  [0.8, 8.9, 5.6, 3.4, 'rain'],
#  [1.0, 8.3, 5.0, 1.3, 'rain'],
#  [11.4, 7.2, 4.4, 1.4, 'rain'],
#  [2.5, 6.7, 1.1, 3.1, 'rain'],
#  [0.0, 7.2, 0.6, 1.8, 'drizzle'],
#  [1.8, 7.2, 3.3, 2.1, 'rain'],
#  [17.3, 10.0, 4.4, 3.4, 'rain'],
#  [6.4, 6.7, 3.9, 8.1, 'rain'],
#  [0.0, 6.7, 2.2, 4.7, 'sun'],
#  [3.0, 7.8, 1.7, 2.9, 'rain'],
#  [0.8, 10.0, 7.8, 7.5, 'rain'],
#  [8.6, 10.0, 2.8, 5.9, 'rain'],
#  [0.0, 8.3, 2.8, 3.9, 'sun'],
#  [11.4, 6.7, 4.4, 3.5, 'rain'],
#  [0.0, 7.2, 2.8, 6.4, 'rain'],
#  [1.3, 5.0, -1.1, 3.4, 'snow'],
#  [0.0, 6.7, -2.2, 3.0, 'sun'],
#  [3.6, 6.7, -0.6, 4.2, 'snow'],
#  [0.8, 5.0, 1.1, 7.0, 'snow'],
#  [0.0, 6.1, 1.1, 3.1, 'sun'],
#  [2.0, 6.7, 3.9, 5.1, 'rain'],
#  [0.0, 12.2, 6.7, 7.0, 'sun'],
#  [0.0, 10.6, 6.7, 5.6, 'rain'],
#  [6.9, 7.8, 1.1, 6.2, 'rain'],
#  [0.5, 6.7, 0.0, 2.7, 'snow'],
#  [0.0, 8.9, -1.7, 2.7, 'sun'],
#  [0.0, 15.6, 0.6, 2.5, 'sun'],
#  [3.6, 9.4, 5.0, 2.8, 'rain'],
#  [10.4, 7.2, 6.1, 3.4, 'rain'],
#  [13.7, 6.7, 2.8, 5.8, 'rain'],
#  [19.3, 8.3, 0.6, 6.2, 'snow'],
#  [9.4, 5.6, 0.6, 5.3, 'snow'],
#  [8.6, 7.8, 1.1, 4.7, 'rain'],
#  [23.9, 11.1, 5.6, 5.8, 'snow'],
#  [8.4, 8.9, 3.9, 5.1, 'rain'],
#  [9.4, 10.0, 0.6, 3.8, 'snow'],
#  [3.6, 5.0, -0.6, 2.7, 'rain'],
#  [2.0, 7.2, -1.1, 3.0, 'rain'],
#  [3.6, 7.8, 2.2, 6.4, 'rain'],
#  [1.3, 8.9, 1.1, 2.5, 'rain'],
#  [4.1, 10.0, 1.7, 2.1, 'rain'],
#  [0.0, 12.2, 0.6, 2.8, 'sun'],
#  [0.0, 15.0, 3.3, 5.2, 'sun'],
#  [0.0, 13.3, 2.2, 2.7, 'rain'],
#  [0.0, 12.8, 6.1, 4.3, 'drizzle'],
#  [4.8, 14.4, 6.7, 3.8, 'rain'],
#  [1.3, 10.6, 7.2, 5.9, 'rain'],
#  [27.4, 10.0, 6.1, 4.4, 'rain'],
#  [5.6, 9.4, 5.0, 4.7, 'rain'],
#  [13.2, 10.0, 2.8, 3.4, 'rain'],
#  [1.5, 8.9, 4.4, 6.8, 'rain'],
#  [0.0, 16.7, 4.4, 3.1, 'sun'],
#  [1.5, 11.7, 3.3, 3.1, 'rain'],
#  [0.0, 10.6, 2.8, 2.1, 'sun'],
#  [4.6, 9.4, 2.8, 1.8, 'snow'],
#  [0.3, 11.1, 3.3, 2.6, 'rain'],
#  [0.0, 16.1, 1.7, 4.3, 'sun'],
#  [0.0, 21.1, 7.2, 4.1, 'sun'],
#  [0.0, 20.0, 6.1, 2.1, 'sun'],
#  [0.0, 17.8, 8.9, 3.2, 'rain'],
#  [2.3, 11.1, 7.2, 2.6, 'rain'],
#  [0.5, 13.9, 5.6, 2.6, 'rain'],
#  [0.0, 15.0, 3.9, 4.0, 'drizzle'],
#  [0.0, 15.6, 3.3, 3.0, 'sun'],
#  [0.0, 16.1, 7.2, 2.9, 'rain'],
#  [8.1, 13.3, 6.7, 5.8, 'rain'],
#  [1.8, 10.0, 4.4, 2.0, 'rain'],
#  [1.8, 13.3, 7.2, 3.9, 'rain'],
#  [10.9, 13.9, 5.0, 2.6, 'rain'],
#  [6.6, 13.3, 6.7, 2.7, 'rain'],
#  [0.0, 20.0, 4.4, 2.3, 'sun'],
#  [0.0, 23.3, 8.3, 2.6, 'rain'],
#  [0.0, 21.7, 8.9, 3.5, 'sun'],
#  [4.3, 13.9, 10.0, 2.8, 'rain'],
#  [10.7, 16.7, 8.9, 2.6, 'rain'],
#  [3.8, 13.9, 6.7, 5.2, 'rain'],
#  [0.8, 13.3, 6.1, 4.8, 'rain'],
#  [0.0, 16.1, 8.3, 2.5, 'drizzle'],
#  [4.3, 15.6, 8.9, 1.6, 'rain'],
#  [4.3, 12.8, 7.2, 8.0, 'rain'],
#  [0.5, 11.7, 6.1, 6.4, 'rain'],
#  [0.5, 13.3, 5.6, 2.5, 'rain'],
#  [18.5, 11.1, 7.2, 3.4, 'rain'],
#  [1.8, 12.2, 6.1, 4.6, 'rain'],
#  [0.0, 13.3, 5.0, 2.3, 'sun'],
#  [0.0, 17.8, 5.0, 2.4, 'sun'],
#  [0.0, 23.9, 6.1, 2.2, 'sun'],
#  [0.0, 18.3, 9.4, 3.0, 'sun'],
#  [0.0, 13.3, 6.7, 3.9, 'rain'],
#  [0.0, 14.4, 3.9, 3.0, 'sun'],
#  [0.0, 18.3, 4.4, 4.3, 'sun'],
#  [0.0, 24.4, 6.7, 3.4, 'sun'],
#  [0.0, 25.6, 9.4, 4.2, 'sun'],
#  [0.0, 26.7, 12.8, 3.8, 'sun'],
#  [0.0, 24.4, 9.4, 4.1, 'drizzle'],
#  [0.0, 19.4, 9.4, 3.5, 'sun'],
#  [0.0, 17.8, 6.7, 2.9, 'rain'],
#  [0.0, 15.6, 7.8, 3.1, 'rain'],
#  [0.0, 19.4, 7.2, 1.5, 'sun'],
#  [6.4, 14.4, 11.7, 1.3, 'rain'],
#  [14.0, 16.7, 10.0, 4.0, 'rain'],
#  [6.1, 12.8, 8.9, 4.8, 'rain'],
#  [0.3, 14.4, 8.9, 6.3, 'rain'],
#  [0.0, 17.2, 8.9, 3.3, 'rain'],
#  [0.0, 22.2, 8.9, 3.1, 'rain'],
#  [0.0, 22.2, 8.9, 3.6, 'sun'],
#  [0.0, 17.2, 11.7, 3.7, 'sun'],
#  [0.0, 16.7, 10.0, 3.4, 'rain'],
#  [0.0, 16.1, 7.8, 1.8, 'sun'],
#  [0.3, 18.9, 11.1, 1.5, 'rain'],
#  [3.8, 17.8, 12.2, 2.7, 'rain'],
#  [6.6, 20.0, 12.8, 3.7, 'rain'],
#  [0.3, 18.9, 10.6, 3.7, 'rain'],
#  [0.0, 17.2, 9.4, 2.9, 'sun'],
#  [1.3, 12.8, 8.9, 3.1, 'rain'],
#  [16.0, 13.3, 8.3, 3.3, 'rain'],
#  [0.0, 16.1, 6.1, 3.4, 'sun'],
#  [16.5, 16.1, 8.9, 3.5, 'rain'],
#  [1.5, 15.0, 8.3, 3.0, 'rain'],
#  [0.0, 17.2, 8.3, 4.7, 'rain'],
#  [0.0, 18.9, 10.0, 2.9, 'sun'],
#  [0.0, 23.3, 10.0, 1.8, 'rain'],
#  [0.8, 18.3, 12.8, 3.9, 'rain'],
#  [0.0, 16.1, 11.1, 4.3, 'sun'],
#  [0.0, 17.2, 10.0, 2.7, 'sun'],
#  [0.0, 22.2, 9.4, 1.7, 'sun'],
#  [0.0, 21.1, 15.0, 4.1, 'rain'],
#  [0.0, 18.9, 11.7, 6.4, 'sun'],
#  [3.0, 17.2, 10.0, 3.8, 'rain'],
#  [1.0, 19.4, 10.0, 3.0, 'rain'],
#  [0.0, 24.4, 10.0, 3.0, 'sun'],
#  [0.0, 23.9, 11.7, 2.1, 'sun'],
#  [15.7, 13.9, 11.7, 1.9, 'rain'],
#  [8.6, 15.6, 9.4, 2.5, 'rain'],
#  [0.0, 19.4, 9.4, 2.0, 'drizzle'],
#  [0.5, 19.4, 11.1, 3.1, 'rain'],
#  [0.0, 18.3, 10.6, 3.4, 'rain'],
#  [0.0, 22.8, 8.9, 1.8, 'sun'],
#  [0.0, 22.2, 11.7, 2.5, 'rain'],
#  [0.3, 21.7, 15.0, 1.9, 'rain'],
#  [3.0, 20.0, 13.3, 2.4, 'rain'],
#  [0.0, 20.0, 12.2, 2.3, 'rain'],
#  [2.0, 18.9, 11.7, 2.1, 'rain'],
#  [5.8, 18.3, 10.6, 6.0, 'rain'],
#  [0.0, 20.6, 9.4, 3.8, 'sun'],
#  [0.0, 24.4, 10.6, 3.1, 'drizzle'],
#  [0.0, 25.0, 11.1, 2.1, 'sun'],
#  [0.0, 26.7, 12.8, 3.8, 'sun'],
#  [0.0, 28.3, 14.4, 2.8, 'rain'],
#  [1.5, 25.0, 12.8, 2.0, 'rain'],
#  [0.0, 23.9, 11.1, 2.3, 'drizzle'],
#  [0.0, 27.8, 13.3, 2.9, 'fog'],
#  [0.0, 25.6, 13.3, 2.7, 'drizzle'],
#  [0.5, 23.3, 13.9, 2.2, 'rain'],
#  [0.0, 25.0, 15.0, 2.2, 'rain'],
#  [0.0, 18.9, 13.3, 3.8, 'rain'],
#  [0.3, 26.1, 13.3, 2.5, 'rain'],
#  [0.0, 21.7, 15.0, 2.6, 'sun'],
#  [0.0, 21.1, 14.4, 2.9, 'sun'],
#  [0.0, 25.0, 14.4, 2.2, 'sun'],
#  [15.2, 19.4, 13.9, 4.0, 'rain'],
#  [0.0, 23.9, 13.9, 2.3, 'sun'],
#  [1.0, 20.6, 12.2, 3.9, 'rain'],
#  [0.0, 18.9, 11.1, 3.3, 'rain'],
#  [0.0, 23.3, 12.2, 4.3, 'sun'],
#  [0.0, 26.7, 12.8, 2.6, 'sun'],
#  [0.0, 25.6, 12.8, 2.2, 'drizzle'],
#  [0.0, 18.9, 13.9, 2.8, 'drizzle'],
#  [0.0, 22.2, 13.3, 1.7, 'drizzle'],
#  [0.0, 22.8, 15.0, 2.0, 'sun'],
#  [0.0, 19.4, 13.3, 3.0, 'sun'],
#  [0.0, 22.8, 13.9, 2.8, 'sun'],
#  [0.0, 23.9, 13.3, 2.2, 'drizzle'],
#  [0.0, 23.3, 12.2, 2.5, 'sun'],
#  [0.0, 27.2, 12.8, 3.9, 'sun'],
#  [0.0, 33.9, 16.7, 3.7, 'sun'],
#  [0.0, 33.9, 17.8, 1.9, 'sun'],
#  [0.0, 28.3, 15.6, 2.5, 'rain'],
#  [0.0, 21.1, 15.0, 2.6, 'drizzle'],
#  [0.0, 22.2, 15.0, 3.1, 'sun'],
#  [0.0, 24.4, 14.4, 3.8, 'drizzle'],
#  [0.0, 25.6, 12.2, 2.3, 'sun'],
#  [0.0, 28.3, 13.3, 2.5, 'sun'],
#  [0.0, 30.6, 15.0, 3.0, 'sun'],
#  [0.0, 30.6, 15.0, 2.8, 'sun'],
#  [0.0, 28.9, 13.9, 2.8, 'sun'],
#  [0.0, 31.1, 16.7, 4.7, 'sun'],
#  [0.0, 34.4, 18.3, 2.8, 'sun'],
#  [0.0, 32.8, 16.1, 1.8, 'sun'],
#  [0.0, 21.7, 14.4, 3.0, 'drizzle'],
#  [0.0, 23.3, 15.0, 2.7, 'drizzle'],
#  [0.0, 25.6, 15.0, 1.9, 'sun'],
#  [0.0, 23.3, 13.3, 3.0, 'rain'],
#  [0.0, 22.2, 13.3, 2.3, 'sun'],
#  [0.0, 21.1, 13.9, 3.8, 'sun'],
#  [0.0, 22.2, 10.0, 3.3, 'sun'],
#  [0.0, 26.1, 11.7, 3.2, 'sun'],
#  [0.0, 21.1, 12.2, 3.4, 'sun'],
#  [0.0, 23.9, 13.3, 1.8, 'sun'],
#  [0.0, 22.8, 12.2, 3.2, 'sun'],
#  [0.0, 22.8, 13.3, 2.4, 'sun'],
#  [0.0, 22.8, 12.8, 1.9, 'sun'],
#  [0.0, 22.2, 10.6, 2.9, 'sun'],
#  [0.0, 21.7, 10.6, 2.1, 'sun'],
#  [0.0, 21.1, 10.0, 2.0, 'sun'],
#  [0.0, 22.8, 12.8, 3.3, 'sun'],
#  [0.0, 24.4, 11.1, 3.1, 'sun'],
#  [0.0, 26.1, 11.7, 2.6, 'sun'],
#  [0.0, 28.3, 14.4, 4.2, 'sun'],
#  [0.0, 32.2, 13.3, 3.1, 'sun'],
#  [0.0, 25.0, 13.3, 3.0, 'sun'],
#  [0.3, 18.9, 13.9, 5.0, 'rain'],
#  [0.3, 20.0, 11.7, 3.9, 'rain'],
#  [0.0, 20.0, 8.9, 4.2, 'sun'],
#  [0.0, 22.2, 10.0, 5.6, 'sun'],
#  [0.0, 27.8, 11.7, 3.6, 'sun'],
#  [0.0, 26.1, 11.1, 1.5, 'sun'],
#  [0.0, 22.2, 11.1, 1.9, 'sun'],
#  [0.0, 24.4, 9.4, 2.3, 'sun'],
#  [0.0, 27.8, 11.7, 2.2, 'fog'],
#  [0.0, 27.8, 11.7, 1.4, 'sun'],
#  [0.0, 23.9, 11.7, 1.9, 'drizzle'],
#  [0.0, 19.4, 10.0, 2.5, 'drizzle'],
#  [0.0, 16.1, 12.8, 2.1, 'drizzle'],
#  [0.3, 19.4, 11.7, 1.1, 'rain'],
#  [0.0, 19.4, 10.0, 1.4, 'fog'],
#  [0.0, 21.1, 10.0, 1.8, 'fog'],
#  [0.0, 19.4, 11.1, 1.7, 'sun'],
#  [0.0, 19.4, 9.4, 1.7, 'drizzle'],
#  [0.0, 22.8, 10.0, 1.7, 'drizzle'],
#  [0.0, 25.0, 12.2, 1.1, 'rain'],
#  [0.0, 20.6, 12.2, 4.3, 'sun'],
#  [0.0, 21.1, 7.8, 3.1, 'sun'],
#  [0.0, 23.3, 8.9, 3.0, 'sun'],
#  [0.0, 17.8, 10.0, 4.1, 'sun'],
#  [0.0, 18.9, 7.8, 7.3, 'sun'],
#  [0.0, 18.9, 8.3, 6.5, 'sun'],
#  [0.0, 21.7, 8.9, 5.7, 'sun'],
#  [0.0, 23.9, 7.8, 5.1, 'sun'],
#  [0.0, 23.9, 7.8, 1.3, 'sun'],
#  [0.0, 21.1, 7.8, 1.9, 'sun'],
#  [0.0, 16.1, 8.9, 1.6, 'drizzle'],
#  [0.0, 12.2, 8.3, 1.4, 'drizzle'],
#  [0.0, 13.9, 7.2, 1.3, 'drizzle'],
#  [2.0, 13.9, 8.9, 4.6, 'rain'],
#  [4.8, 15.6, 12.2, 3.9, 'rain'],
#  [16.5, 17.8, 13.3, 3.4, 'rain'],
#  [7.9, 17.2, 11.1, 4.6, 'rain'],
#  [0.0, 16.1, 8.3, 5.5, 'sun'],
#  [0.0, 14.4, 6.1, 1.6, 'sun'],
#  [20.8, 17.8, 6.7, 2.0, 'rain'],
#  [4.8, 15.0, 9.4, 5.3, 'rain'],
#  [0.5, 11.1, 6.1, 5.7, 'rain'],
#  [6.4, 11.7, 4.4, 2.7, 'rain'],
#  [8.9, 7.8, 3.3, 2.6, 'rain'],
#  [0.0, 11.1, 5.6, 3.0, 'rain'],
#  [7.1, 11.7, 6.1, 2.1, 'rain'],
#  [0.0, 11.7, 6.7, 1.5, 'sun'],
#  [1.5, 11.1, 7.2, 2.5, 'rain'],
#  [23.1, 14.4, 9.4, 5.1, 'rain'],
#  [6.1, 14.4, 10.0, 3.8, 'rain'],
#  [10.9, 15.6, 10.0, 4.9, 'rain'],
#  [34.5, 15.0, 12.2, 2.8, 'rain'],
#  [14.5, 15.6, 11.1, 2.7, 'rain'],
#  [9.7, 15.0, 10.6, 3.0, 'rain'],
#  [5.6, 15.0, 10.6, 1.0, 'rain'],
#  [0.5, 15.6, 11.1, 3.6, 'rain'],
#  [8.1, 17.8, 12.8, 3.8, 'rain'],
#  [0.8, 15.0, 7.8, 4.0, 'rain'],
#  [0.3, 12.8, 6.7, 3.5, 'rain'],
#  [0.0, 12.2, 3.9, 3.4, 'rain'],
#  [0.0, 10.0, 1.1, 3.4, 'rain'],
#  [0.0, 8.9, 1.1, 2.0, 'rain'],
#  [0.0, 7.8, -0.6, 2.2, 'sun'],
#  [15.2, 8.9, 1.1, 3.0, 'rain'],
#  [3.6, 12.8, 6.1, 3.0, 'rain'],
#  [5.3, 11.1, 7.8, 2.5, 'rain'],
#  [0.8, 11.1, 5.0, 2.6, 'rain'],
#  [0.0, 9.4, 2.8, 2.4, 'drizzle'],
#  [5.6, 9.4, 2.2, 1.6, 'rain'],
#  [6.1, 12.2, 6.1, 5.3, 'rain'],
#  [7.9, 10.0, 6.1, 4.9, 'rain'],
#  [54.1, 13.3, 8.3, 6.0, 'rain'],
#  [3.8, 11.1, 7.2, 4.2, 'rain'],
#  [11.2, 8.3, 3.9, 5.5, 'rain'],
#  [0.0, 8.9, 2.8, 1.5, 'rain'],
#  [32.0, 9.4, 6.1, 2.4, 'rain'],
#  [0.0, 8.9, 3.9, 1.2, 'rain'],
#  [0.0, 8.3, 1.1, 3.6, 'drizzle'],
#  [0.0, 9.4, 1.7, 3.8, 'fog'],
#  [0.0, 10.0, 1.7, 1.5, 'sun'],
#  [2.8, 9.4, 2.2, 2.9, 'rain'],
#  [1.5, 12.8, 7.8, 4.2, 'rain'],
#  [35.6, 15.0, 7.8, 4.6, 'rain'],
#  [4.1, 13.3, 8.3, 5.5, 'rain'],
#  [19.6, 8.3, 7.2, 6.2, 'rain'],
#  [13.0, 9.4, 7.2, 4.4, 'rain'],
#  [14.2, 11.7, 7.2, 6.2, 'rain'],
#  [1.5, 8.9, 4.4, 5.0, 'rain'],
#  [1.5, 7.2, 6.1, 5.1, 'rain'],
#  [1.0, 7.8, 3.3, 4.6, 'rain'],
#  [0.0, 6.7, 3.3, 2.0, 'sun'],
#  [1.5, 6.7, 2.8, 2.1, 'rain'],
#  [0.5, 7.2, 5.6, 1.8, 'rain'],
#  [3.0, 7.8, 5.6, 4.5, 'rain'],
#  [8.1, 6.7, 4.4, 2.0, 'rain'],
#  [2.3, 7.2, 3.3, 2.8, 'rain'],
#  [7.9, 6.1, 1.1, 1.7, 'rain'],
#  [5.3, 4.4, 0.6, 5.1, 'snow'],
#  [22.6, 6.7, 3.3, 5.5, 'snow'],
#  [2.0, 8.3, 1.7, 9.5, 'rain'],
#  [3.3, 3.9, 0.6, 5.3, 'snow'],
#  [13.7, 8.3, 1.7, 5.8, 'snow'],
#  [13.2, 7.2, 0.6, 3.7, 'rain'],
#  [1.8, 8.3, -1.7, 1.7, 'rain'],
#  [3.3, 8.3, 3.9, 3.5, 'rain'],
#  [6.6, 7.2, 3.3, 2.5, 'rain'],
#  [0.3, 5.6, 2.8, 2.8, 'rain'],
#  [13.5, 5.6, 2.8, 4.2, 'snow'],
#  [4.6, 6.7, 3.3, 4.9, 'rain'],
#  [4.1, 7.8, 3.3, 3.2, 'rain'],
#  [0.0, 8.3, 3.9, 1.7, 'rain'],
#  [1.5, 5.0, 3.3, 1.7, 'rain'],
#  [0.0, 4.4, 0.0, 1.8, 'drizzle'],
#  [0.0, 3.3, -1.1, 2.0, 'drizzle'],
#  [0.0, 5.0, -2.8, 2.7, 'sun'],
#  [0.0, 6.1, -1.1, 3.2, 'sun'],
#  [4.1, 6.7, -1.7, 3.0, 'rain'],
#  [2.5, 10.0, 2.2, 2.8, 'rain'],
#  [3.0, 6.7, 4.4, 3.1, 'rain'],
#  [2.0, 7.2, 2.8, 3.0, 'rain'],
#  [2.3, 10.0, 4.4, 7.3, 'rain'],
#  [16.3, 11.7, 5.6, 6.3, 'rain'],
#  [38.4, 10.0, 1.7, 5.1, 'rain'],
#  [0.3, 3.3, -0.6, 2.1, 'snow'],
#  [0.0, 2.8, -2.8, 1.9, 'drizzle'],
#  [0.0, 2.8, -3.9, 2.0, 'sun'],
#  [0.0, 2.2, -4.4, 1.5, 'sun'],
#  [0.0, 3.3, -2.2, 1.3, 'sun'],
#  [0.0, 6.7, -0.6, 2.3, 'sun'],
#  [0.0, 6.1, -3.9, 1.8, 'drizzle'],
#  [0.0, 3.9, -2.8, 1.0, 'drizzle'],
#  [0.0, 3.3, -1.1, 1.3, 'drizzle'],
#  [0.0, 1.1, -0.6, 1.9, 'drizzle'],
#  [0.0, 3.3, -0.6, 2.1, 'drizzle'],
#  [0.0, 2.2, -1.7, 1.1, 'drizzle'],
#  [0.0, 3.3, -1.7, 0.6, 'drizzle'],
#  [5.1, 7.2, 2.2, 3.1, 'rain'],
#  [5.8, 7.2, 1.1, 2.6, 'rain'],
#  [3.0, 10.6, 2.8, 2.1, 'rain'],
#  [2.3, 8.3, 3.9, 4.5, 'rain'],
#  [1.8, 5.6, 3.9, 4.5, 'rain'],
#  [7.9, 6.1, 3.3, 3.2, 'rain'],
#  [4.3, 8.3, 5.0, 3.9, 'rain'],
#  [3.6, 8.9, 6.7, 3.9, 'rain'],
#  [3.0, 9.4, 7.2, 4.0, 'rain'],
#  [0.3, 11.7, 5.0, 2.9, 'rain'],
#  [0.0, 6.1, 2.8, 2.0, 'drizzle'],
#  [2.3, 8.9, 2.8, 2.9, 'rain'],
#  [0.0, 10.6, 6.7, 2.6, 'rain'],
#  [3.3, 10.0, 6.7, 5.1, 'rain'],
#  [1.0, 10.6, 6.1, 4.5, 'rain'],
#  [1.3, 9.4, 3.3, 4.1, 'rain'],
#  [0.0, 7.8, 2.2, 1.3, 'sun'],
#  [0.3, 8.3, 4.4, 1.3, 'rain'],
#  [0.0, 8.9, 1.7, 2.0, 'drizzle'],
#  [0.3, 8.3, 4.4, 1.4, 'rain'],
#  [1.0, 11.1, 7.2, 5.6, 'rain'],
#  [2.3, 9.4, 7.2, 4.1, 'rain'],
#  [1.0, 9.4, 5.6, 2.2, 'rain'],
#  [0.0, 13.3, 5.0, 2.4, 'drizzle'],
#  [0.0, 11.1, 3.9, 5.6, 'rain'],
#  [0.0, 9.4, 4.4, 3.4, 'rain'],
#  [0.0, 7.8, 3.9, 1.9, 'rain'],
#  [0.0, 10.6, 1.7, 3.4, 'sun'],
#  [1.5, 7.8, 1.1, 2.1, 'rain'],
#  [0.5, 6.7, 3.9, 6.2, 'rain'],
#  [9.4, 7.8, 3.9, 8.1, 'rain'],
#  [0.3, 10.0, 3.9, 4.6, 'rain'],
#  [0.0, 8.9, 5.0, 5.5, 'rain'],
#  [2.3, 10.6, 3.3, 7.1, 'rain'],
#  [0.5, 8.9, 3.9, 3.8, 'rain'],
#  [4.6, 10.0, 4.4, 1.8, 'rain'],
#  [8.1, 11.7, 6.7, 3.8, 'rain'],
#  [4.1, 15.0, 11.1, 5.4, 'rain'],
#  [0.8, 13.9, 5.0, 4.5, 'rain'],
#  [0.0, 11.1, 2.2, 2.8, 'sun'],
#  [0.0, 13.3, 0.0, 3.9, 'sun'],
#  [0.0, 9.4, 6.1, 2.4, 'rain'],
#  [11.9, 7.2, 5.0, 4.1, 'rain'],
#  [7.4, 12.2, 5.0, 2.5, 'rain'],
#  [0.0, 11.7, 2.2, 2.6, 'drizzle'],
#  [0.0, 12.8, 1.1, 1.3, 'fog'],
#  [0.8, 7.8, 3.9, 1.6, 'rain'],
#  [1.3, 10.6, 6.1, 1.1, 'rain'],
#  [2.0, 12.8, 10.0, 5.7, 'rain'],
#  [2.3, 11.7, 9.4, 3.7, 'rain'],
#  [2.8, 11.7, 9.4, 3.0, 'rain'],
#  [0.0, 14.4, 8.9, 4.3, 'rain'],
#  [4.3, 10.6, 4.4, 6.4, 'rain'],
#  [0.0, 8.9, 3.9, 6.1, 'sun'],
#  [0.0, 11.7, 3.9, 5.9, 'rain'],
#  [11.7, 12.8, 1.7, 3.4, 'rain'],
#  [9.9, 11.1, 4.4, 7.6, 'rain'],
#  [8.1, 10.0, 2.2, 4.9, 'snow'],
#  [0.0, 9.4, 0.6, 2.2, 'sun'],
#  [0.0, 10.0, 1.1, 2.6, 'sun'],
#  [0.0, 12.2, 0.6, 2.1, 'sun'],
#  [0.0, 16.7, 4.4, 2.8, 'sun'],
#  [0.0, 16.7, 6.1, 1.7, 'sun'],
#  [0.3, 13.3, 7.2, 1.6, 'rain'],
#  [2.0, 16.1, 8.3, 1.3, 'rain'],
#  [0.0, 18.3, 7.8, 2.5, 'rain'],
#  [0.0, 20.0, 5.6, 4.4, 'drizzle'],
#  [0.0, 20.6, 6.7, 2.9, 'sun'],
#  [0.0, 17.2, 8.3, 3.6, 'sun'],
#  [0.0, 13.9, 8.9, 2.2, 'sun'],
#  [0.0, 16.7, 7.8, 1.6, 'sun'],
#  [8.4, 14.4, 10.0, 3.0, 'rain'],
#  [18.5, 13.9, 10.0, 5.6, 'rain'],
#  [12.7, 12.2, 7.2, 5.0, 'rain'],
#  [39.1, 8.3, 5.0, 3.9, 'rain'],
#  [0.8, 13.3, 6.1, 3.1, 'rain'],
#  [0.0, 12.2, 6.1, 2.4, 'sun'],
#  [9.4, 15.0, 8.9, 6.4, 'rain'],
#  [1.5, 12.2, 6.7, 3.8, 'rain'],
#  [9.7, 7.8, 4.4, 4.6, 'rain'],
#  [9.4, 10.6, 3.3, 5.7, 'rain'],
#  [5.8, 12.8, 4.4, 2.3, 'rain'],
#  [0.0, 13.9, 4.4, 2.4, 'fog'],
#  [0.3, 13.9, 3.3, 2.6, 'rain'],
#  [0.0, 15.0, 3.9, 3.3, 'drizzle'],
#  [5.3, 11.7, 6.7, 4.0, 'rain'],
#  [20.6, 13.3, 9.4, 4.9, 'rain'],
#  [0.0, 13.9, 8.3, 5.8, 'sun'],
#  [3.3, 12.2, 6.7, 4.1, 'rain'],
#  [0.0, 16.1, 5.0, 4.3, 'sun'],
#  [0.0, 17.8, 3.9, 2.8, 'sun'],
#  [0.0, 21.1, 6.1, 3.0, 'sun'],
#  [0.0, 21.7, 6.7, 1.1, 'sun'],
#  [0.0, 20.6, 8.3, 2.2, 'fog'],
#  [0.0, 13.9, 10.6, 5.9, 'sun'],
#  [1.0, 15.0, 9.4, 5.2, 'rain'],
#  [3.8, 13.9, 6.7, 4.2, 'rain'],
#  [0.0, 12.8, 4.4, 2.4, 'sun'],
#  [0.0, 18.3, 3.3, 3.1, 'sun'],
#  [0.0, 20.6, 6.7, 4.0, 'sun'],
#  [0.0, 21.7, 9.4, 4.9, 'sun'],
#  [0.0, 25.0, 11.1, 6.5, 'sun'],
#  [0.0, 28.9, 11.7, 5.3, 'sun'],
#  [0.0, 30.6, 12.2, 2.0, 'sun'],
#  [0.0, 20.6, 11.1, 3.3, 'sun'],
#  [0.0, 19.4, 11.1, 1.9, 'sun'],
#  [0.0, 22.8, 10.0, 1.3, 'sun'],
#  [0.0, 26.1, 9.4, 1.0, 'sun'],
#  [0.0, 27.2, 12.2, 2.6, 'sun'],
#  [6.6, 21.7, 13.9, 3.9, 'rain'],
#  [3.3, 18.9, 9.4, 5.0, 'rain'],
#  [0.0, 18.3, 7.8, 2.4, 'sun'],
#  [1.0, 17.2, 8.9, 2.3, 'rain'],
#  [0.0, 21.7, 12.2, 2.7, 'fog'],
#  [0.5, 17.2, 11.7, 3.7, 'rain'],
#  [0.0, 16.7, 11.1, 2.9, 'sun'],
#  [0.0, 18.3, 10.6, 2.3, 'sun'],
#  [0.0, 19.4, 9.4, 1.8, 'sun'],
#  [13.7, 15.6, 8.3, 4.8, 'rain'],
#  [13.7, 11.1, 7.2, 3.0, 'rain'],
#  [4.1, 12.2, 6.7, 1.9, 'rain'],
#  [0.3, 16.7, 8.9, 2.7, 'rain'],
#  [0.0, 17.8, 10.0, 2.7, 'sun'],
#  [1.5, 18.3, 10.6, 2.2, 'rain'],
#  [9.7, 16.7, 11.1, 3.1, 'rain'],
#  [0.5, 17.2, 11.7, 2.8, 'rain'],
#  [5.6, 16.1, 9.4, 4.0, 'rain'],
#  [0.0, 16.7, 9.4, 5.3, 'sun'],
#  [0.0, 19.4, 11.1, 2.5, 'sun'],
#  [0.0, 22.8, 12.2, 2.5, 'sun'],
#  [1.0, 20.6, 12.2, 3.1, 'rain'],
#  [0.0, 22.2, 11.1, 2.9, 'sun'],
#  [0.0, 26.1, 12.2, 3.4, 'sun'],
#  [0.0, 26.7, 14.4, 3.1, 'sun'],
#  [0.0, 26.7, 12.2, 2.5, 'sun'],
#  [0.0, 21.7, 13.3, 3.2, 'sun'],
#  [0.0, 20.6, 12.8, 3.1, 'sun'],
#  [0.0, 20.6, 11.1, 3.7, 'sun'],
#  [0.0, 21.7, 11.7, 3.2, 'sun'],
#  [0.0, 20.0, 10.0, 5.7, 'sun'],
#  [0.3, 20.6, 11.7, 4.2, 'rain'],
#  [0.0, 21.1, 11.7, 2.6, 'sun'],
#  [0.0, 20.0, 12.2, 3.7, 'sun'],
#  [0.0, 25.6, 10.0, 2.9, 'sun'],
#  [0.0, 23.9, 12.8, 3.4, 'sun'],
#  [0.0, 25.6, 13.9, 3.0, 'sun'],
#  [0.3, 23.3, 13.3, 3.4, 'rain'],
#  [0.0, 20.0, 12.8, 3.7, 'sun'],
#  [3.0, 17.2, 12.8, 5.0, 'rain'],
#  [0.3, 20.6, 12.2, 1.5, 'rain'],
#  [0.0, 25.6, 11.7, 1.7, 'sun'],
#  [7.9, 22.2, 15.0, 2.1, 'rain'],
#  [4.8, 21.1, 13.9, 3.7, 'rain'],
#  [9.9, 23.3, 14.4, 2.8, 'rain'],
#  [2.0, 22.2, 15.0, 2.3, 'rain'],
#  [3.6, 21.1, 16.7, 1.3, 'rain'],
#  [0.0, 30.6, 16.1, 2.2, 'sun'],
#  [0.0, 30.0, 18.3, 1.7, 'sun'],
#  [0.0, 33.9, 17.2, 2.5, 'sun'],
#  [0.0, 31.7, 18.3, 2.3, 'sun'],
#  [0.0, 28.3, 15.6, 3.0, 'sun'],
#  [0.0, 26.1, 16.7, 3.2, 'sun'],
#  [0.0, 21.7, 13.9, 2.2, 'fog'],
#  [0.0, 23.3, 13.9, 2.6, 'sun'],
#  [0.0, 26.1, 13.3, 2.2, 'sun'],
#  [0.0, 23.9, 13.9, 2.9, 'sun'],
#  [0.0, 26.7, 13.3, 2.8, 'sun'],
#  [0.0, 30.0, 15.0, 2.5, 'sun'],
#  [0.0, 22.2, 13.9, 2.6, 'sun'],
#  [0.0, 22.8, 12.2, 3.0, 'sun'],
#  [0.0, 19.4, 13.3, 2.2, 'sun'],
#  [0.0, 26.1, 11.1, 3.1, 'sun'],
#  [0.0, 27.8, 12.8, 3.0, 'sun'],
#  [0.0, 27.8, 14.4, 4.6, 'sun'],
#  [0.0, 31.1, 18.3, 4.1, 'sun'],
#  [0.0, 22.2, 15.0, 3.7, 'sun'],
#  [0.0, 26.1, 13.9, 2.0, 'sun'],
#  [0.0, 27.8, 13.3, 1.9, 'sun'],
#  [0.0, 25.0, 13.3, 2.0, 'sun'],
#  [0.0, 23.9, 12.8, 2.3, 'sun'],
#  [0.0, 26.1, 13.3, 2.4, 'fog'],
#  [0.0, 31.1, 13.9, 3.0, 'sun'],
#  [0.0, 31.1, 14.4, 2.5, 'sun'],
#  [0.0, 31.1, 12.8, 2.3, 'sun'],
#  [0.0, 31.1, 14.4, 2.9, 'sun'],
#  [0.0, 25.6, 12.8, 2.6, 'sun'],
#  [0.0, 21.1, 12.2, 3.4, 'fog'],
#  [0.0, 25.0, 13.3, 1.4, 'sun'],
#  [0.0, 25.0, 13.3, 2.8, 'sun'],
#  [0.0, 21.7, 13.3, 1.8, 'sun'],
#  [0.0, 20.6, 13.3, 3.9, 'sun'],
#  [2.0, 17.2, 15.0, 2.0, 'rain'],
#  [0.0, 25.0, 15.6, 2.4, 'fog'],
#  [0.0, 28.9, 15.0, 3.4, 'sun'],
#  [0.0, 30.0, 15.0, 2.1, 'sun'],
#  [0.0, 30.6, 13.9, 1.4, 'sun'],
#  [0.0, 31.1, 13.9, 1.9, 'sun'],
#  [0.0, 28.3, 14.4, 2.5, 'sun'],
#  [0.0, 28.3, 14.4, 2.1, 'sun'],
#  [2.3, 25.6, 15.0, 2.9, 'rain'],
#  [0.0, 25.0, 14.4, 2.9, 'sun'],
#  [0.0, 25.6, 16.1, 1.9, 'sun'],
#  [0.0, 27.8, 15.0, 1.8, 'sun'],
#  [0.8, 27.2, 15.0, 2.0, 'rain'],
#  [1.8, 21.1, 17.2, 1.0, 'rain'],
#  [0.0, 28.9, 16.1, 2.2, 'fog'],
#  [0.0, 25.6, 17.2, 3.0, 'sun'],
#  [0.0, 26.1, 15.6, 3.1, 'sun'],
#  [0.0, 26.7, 15.6, 3.0, 'sun'],
#  [0.0, 25.6, 16.1, 4.6, 'sun'],
#  [0.0, 27.8, 15.0, 4.3, 'sun'],
#  [0.0, 28.9, 15.0, 1.9, 'sun'],
#  [0.0, 25.0, 16.1, 4.1, 'sun'],
#  [0.0, 25.0, 16.7, 2.7, 'sun'],
#  [0.3, 22.2, 16.1, 2.6, 'rain'],
#  [1.0, 24.4, 16.1, 1.9, 'rain'],
#  [1.3, 26.7, 17.2, 1.4, 'rain'],
#  [5.6, 26.7, 15.6, 1.3, 'rain'],
#  [19.3, 23.9, 18.3, 3.0, 'rain'],
#  [0.0, 26.1, 16.1, 2.9, 'sun'],
#  [0.0, 27.8, 13.9, 2.6, 'sun'],
#  [0.0, 27.8, 15.6, 2.5, 'sun'],
#  [0.0, 27.8, 17.2, 2.1, 'sun'],
#  [2.3, 25.0, 16.7, 1.7, 'rain'],
#  [0.3, 22.8, 16.1, 2.4, 'rain'],
#  [27.7, 20.0, 15.6, 2.5, 'rain'],
#  [21.3, 21.7, 16.1, 2.6, 'rain'],
#  [0.0, 23.3, 17.2, 2.0, 'sun'],
#  [0.0, 26.7, 14.4, 1.5, 'fog'],
#  [0.0, 26.1, 13.9, 2.1, 'sun'],
#  [0.0, 26.7, 15.0, 3.7, 'sun'],
#  [0.0, 33.9, 16.1, 2.4, 'sun'],
#  [0.0, 25.6, 15.0, 1.7, 'sun'],
#  [0.0, 18.9, 15.6, 2.0, 'sun'],
#  [0.0, 21.7, 15.6, 1.4, 'fog'],
#  [3.3, 18.9, 14.4, 2.2, 'rain'],
#  [0.3, 21.7, 15.0, 4.3, 'rain'],
#  [0.0, 17.8, 13.9, 2.3, 'sun'],
#  [0.0, 21.1, 13.3, 2.5, 'sun'],
#  [0.0, 25.6, 10.0, 1.5, 'sun'],
#  [3.6, 23.3, 13.3, 3.0, 'rain'],
#  [0.0, 21.1, 13.3, 2.5, 'sun'],
#  [13.5, 17.2, 13.3, 5.5, 'rain'],
#  [2.8, 16.1, 11.1, 4.5, 'rain'],
#  [0.0, 17.8, 10.0, 2.6, 'sun'],
#  [2.0, 16.1, 9.4, 3.0, 'rain'],
#  [0.0, 17.2, 7.2, 2.2, 'sun'],
#  [1.0, 13.9, 10.6, 4.3, 'rain'],
#  [43.4, 16.7, 11.7, 6.0, 'rain'],
#  [16.8, 14.4, 11.1, 7.1, 'rain'],
#  [18.5, 13.9, 10.0, 6.3, 'rain'],
#  [7.9, 14.4, 8.9, 4.7, 'rain'],
#  [5.3, 12.8, 9.4, 2.4, 'rain'],
#  [0.8, 14.4, 8.9, 0.9, 'rain'],
#  [0.0, 17.8, 5.6, 1.1, 'sun'],
#  [0.0, 20.0, 8.3, 1.6, 'sun'],
#  [4.1, 22.8, 7.8, 2.6, 'rain'],
#  [0.5, 16.1, 11.7, 6.3, 'rain'],
#  [6.9, 13.9, 7.8, 3.0, 'rain'],
#  [0.0, 15.0, 5.6, 1.6, 'sun'],
#  [1.0, 14.4, 8.3, 1.7, 'rain'],
#  [9.1, 13.9, 10.6, 1.0, 'rain'],
#  [1.0, 14.4, 8.9, 2.2, 'rain'],
#  [0.0, 15.0, 6.7, 1.8, 'fog'],
#  [0.0, 15.6, 3.9, 1.6, 'sun'],
#  [0.0, 15.6, 5.0, 0.9, 'sun'],
#  [0.0, 12.8, 8.9, 2.7, 'fog'],
#  [0.0, 14.4, 8.9, 1.7, 'fog'],
#  [0.0, 12.8, 7.2, 1.2, 'sun'],
#  [0.0, 10.6, 7.8, 1.4, 'sun'],
#  [0.0, 10.6, 7.8, 2.4, 'sun'],
#  [0.0, 11.7, 8.3, 2.5, 'sun'],
#  [0.0, 14.4, 7.2, 1.9, 'sun'],
#  [0.0, 12.8, 6.1, 0.4, 'sun'],
#  [0.0, 10.0, 6.1, 0.6, 'sun'],
#  [0.0, 12.2, 7.8, 1.8, 'sun'],
#  [0.0, 11.7, 8.3, 2.7, 'sun'],
#  [1.8, 13.9, 8.3, 4.4, 'rain'],
#  [0.0, 14.4, 7.2, 5.1, 'sun'],
#  [0.0, 13.3, 3.3, 2.2, 'sun'],
#  [0.5, 15.0, 5.6, 3.9, 'rain'],
#  [0.3, 14.4, 10.6, 2.2, 'rain'],
#  [1.3, 17.8, 11.7, 1.4, 'rain'],
#  [12.7, 14.4, 8.3, 7.9, 'rain'],
#  [0.5, 12.2, 4.4, 2.4, 'rain'],
#  [0.0, 10.6, 3.9, 1.6, 'drizzle'],
#  [2.5, 13.3, 7.2, 3.1, 'rain'],
#  [3.8, 12.8, 7.8, 1.7, 'rain'],
#  [30.0, 11.1, 10.0, 7.2, 'rain'],
#  [0.0, 13.3, 7.2, 4.1, 'sun'],
#  [1.8, 11.1, 5.0, 1.4, 'rain'],
#  [0.0, 11.1, 8.3, 4.4, 'sun'],
#  [0.0, 16.1, 6.1, 2.6, 'fog'],
#  [4.1, 15.6, 8.9, 2.2, 'rain'],
#  [0.0, 13.9, 10.6, 3.8, 'sun'],
#  [1.3, 11.1, 6.1, 1.1, 'rain'],
#  [3.0, 10.6, 7.2, 6.0, 'rain'],
#  [0.0, 10.0, 5.0, 4.6, 'sun'],
#  [5.3, 11.7, 7.2, 5.4, 'rain'],
#  [26.2, 12.8, 9.4, 3.9, 'rain'],
#  [1.0, 13.3, 4.4, 5.1, 'rain'],
#  [0.0, 7.8, 1.7, 4.3, 'sun'],
#  [0.0, 7.8, -0.5, 3.6, 'sun'],
#  [0.0, 9.4, 0.0, 4.6, 'sun'],
#  [0.0, 11.1, 1.1, 2.6, 'sun'],
#  [0.0, 11.7, 0.6, 0.9, 'fog'],
#  [0.0, 12.2, 2.2, 0.5, 'sun'],
#  [0.0, 12.2, 2.8, 1.0, 'sun'],
#  [0.0, 14.4, 5.6, 1.3, 'sun'],
#  [0.0, 11.7, 3.3, 0.7, 'sun'],
#  [0.5, 9.4, 5.0, 2.1, 'rain'],
#  [2.3, 11.1, 7.2, 3.9, 'rain'],
#  [3.0, 13.3, 7.8, 8.8, 'rain'],
#  [4.6, 7.8, 1.7, 3.5, 'rain'],
#  [0.0, 5.0, -0.5, 5.6, 'sun'],
#  [0.0, 4.4, -2.1, 1.6, 'sun'],
#  [0.0, 1.1, -4.9, 2.6, 'sun'],
#  [0.0, 1.1, -4.3, 4.7, 'sun'],
#  [0.0, 0.0, -7.1, 3.1, 'sun'],
#  [0.0, 2.2, -6.6, 2.2, 'sun'],
#  [0.0, 1.1, -4.9, 1.3, 'sun'],
#  [0.0, 5.6, 0.6, 1.5, 'sun'],
#  [0.0, 5.0, -1.6, 0.8, 'sun'],
#  [6.9, 5.6, -0.5, 2.3, 'rain'],
#  [0.5, 9.4, 5.6, 2.9, 'rain'],
#  [0.0, 9.4, 6.1, 3.7, 'sun'],
#  [1.3, 11.7, 8.3, 3.9, 'rain'],
#  [0.3, 10.0, 4.4, 1.0, 'rain'],
#  [0.0, 8.3, 4.4, 2.7, 'sun'],
#  [1.3, 7.8, 2.2, 2.8, 'rain'],
#  [0.0, 5.0, 0.0, 2.1, 'sun'],
#  [5.6, 8.3, 0.6, 3.7, 'snow'],
#  [5.6, 8.9, 5.6, 2.3, 'rain'],
#  [10.7, 10.6, 8.3, 4.0, 'rain'],
#  [1.5, 11.7, 6.1, 5.9, 'rain'],
#  [0.0, 8.3, 2.8, 1.7, 'sun'],
#  [0.0, 6.7, 1.7, 0.8, 'sun'],
#  [0.0, 6.7, 0.6, 0.5, 'sun'],
#  [0.3, 8.9, 0.0, 2.1, 'rain'],
#  [0.0, 9.4, 3.3, 1.3, 'sun'],
#  [0.0, 7.2, 1.7, 1.1, 'sun'],
#  [0.3, 8.9, 4.4, 2.6, 'rain'],
#  [0.5, 8.3, 5.0, 1.7, 'rain'],
#  [0.0, 7.2, 3.3, 1.2, 'sun'],
#  [4.1, 10.6, 6.1, 3.2, 'rain'],
#  [1.5, 8.9, 2.8, 2.6, 'rain'],
#  [0.0, 7.8, 0.6, 2.7, 'fog'],
#  [0.0, 8.3, -0.5, 3.7, 'sun'],
#  [0.3, 7.8, -0.5, 2.6, 'rain'],
#  [12.2, 8.3, 5.0, 1.6, 'rain'],
#  [9.7, 10.0, 7.2, 4.6, 'rain'],
#  [5.8, 9.4, 5.6, 6.3, 'rain'],
#  [4.3, 12.8, 8.3, 7.0, 'rain'],
#  [21.3, 14.4, 7.2, 8.8, 'rain'],
#  [1.5, 11.1, 5.6, 8.1, 'rain'],
#  [0.0, 10.6, 10.0, 7.1, 'sun'],
#  [0.0, 11.1, 7.2, 1.3, 'sun'],
#  [0.0, 11.1, 5.6, 2.5, 'sun'],
#  [0.0, 6.7, 4.4, 2.7, 'sun'],
#  [0.0, 5.6, 2.8, 2.3, 'sun'],
#  [0.0, 9.4, 0.6, 2.2, 'sun'],
#  [0.0, 6.1, 3.3, 2.5, 'sun'],
#  [0.0, 10.0, 2.8, 2.2, 'sun'],
#  [0.0, 10.0, 1.7, 1.5, 'sun'],
#  [0.5, 9.4, 5.6, 2.6, 'rain'],
#  [0.0, 10.0, 2.8, 5.2, 'fog'],
#  [0.0, 12.8, 1.1, 1.9, 'sun'],
#  [0.0, 12.2, 1.1, 0.8, 'sun'],
#  [0.0, 8.3, 0.6, 1.3, 'sun'],
#  [0.0, 9.4, 1.7, 1.3, 'sun'],
#  [8.9, 11.1, 6.1, 1.6, 'rain'],
#  [21.6, 11.1, 7.2, 3.4, 'rain'],
#  [0.0, 8.3, 6.1, 6.4, 'sun'],
#  [2.3, 7.8, 5.6, 2.6, 'rain'],
#  [2.0, 7.8, 2.8, 0.8, 'rain'],
#  [0.0, 8.9, 1.1, 2.5, 'sun'],
#  [0.0, 5.0, 0.0, 4.3, 'sun'],
#  [0.0, 2.8, -2.1, 4.7, 'sun'],
#  [0.0, -0.5, -5.5, 6.6, 'sun'],
#  [0.0, -1.6, -6.0, 4.5, 'sun'],
#  [0.0, 3.3, -4.9, 4.2, 'sun'],
#  [5.1, 5.6, -0.5, 4.6, 'snow'],
#  [0.5, 3.9, 0.0, 2.4, 'rain'],
#  [18.3, 10.0, 2.2, 4.7, 'rain'],
#  [17.0, 12.2, 5.6, 3.8, 'rain'],
#  [4.6, 12.2, 7.2, 6.4, 'rain'],
#  [1.8, 12.8, 7.8, 6.3, 'rain'],
#  [9.4, 11.7, 6.1, 6.4, 'rain'],
#  [11.7, 11.1, 5.0, 5.1, 'rain'],
#  [26.4, 9.4, 3.9, 7.9, 'rain'],
#  [14.5, 8.3, 4.4, 5.5, 'rain'],
#  [15.2, 8.9, 5.0, 6.2, 'rain'],
#  [1.0, 8.3, 3.9, 6.0, 'rain'],
#  [3.0, 10.0, 5.6, 6.9, 'rain'],
#  [2.8, 6.7, 3.9, 2.9, 'rain'],
#  [2.5, 5.6, 2.8, 3.1, 'rain'],
#  [6.1, 7.2, 3.9, 2.6, 'rain'],
#  [13.0, 6.7, 3.3, 3.2, 'rain'],
#  [0.3, 12.2, 3.9, 4.5, 'rain'],
#  [0.0, 13.9, 5.6, 2.5, 'sun'],
#  [0.0, 12.8, 4.4, 2.3, 'sun'],
#  [0.0, 14.4, 4.4, 5.9, 'sun'],
#  [0.5, 7.2, 4.4, 4.7, 'rain'],
#  [19.1, 11.1, 2.8, 5.7, 'rain'],
#  [10.7, 14.4, 8.9, 5.1, 'rain'],
#  [16.5, 13.9, 7.8, 3.9, 'rain'],
#  [46.7, 15.6, 10.6, 3.9, 'rain'],
#  [3.0, 13.3, 10.0, 6.2, 'rain'],
#  [0.0, 15.6, 8.9, 4.2, 'sun'],
#  [32.3, 12.8, 6.7, 2.7, 'rain'],
#  [4.3, 15.0, 9.4, 4.3, 'rain'],
#  [18.8, 12.2, 6.1, 2.2, 'rain'],
#  [0.0, 14.4, 4.4, 2.3, 'fog'],
#  [0.0, 16.1, 3.3, 1.9, 'fog'],
#  [0.5, 13.9, 5.0, 2.5, 'rain'],
#  [6.9, 14.4, 8.3, 6.1, 'rain'],
#  [8.1, 16.7, 4.4, 3.0, 'rain'],
#  [27.7, 10.6, 4.4, 3.8, 'rain'],
#  [0.3, 10.0, 2.8, 3.2, 'rain'],
#  [0.0, 10.0, 3.3, 1.6, 'sun'],
#  [0.5, 11.1, 3.3, 5.1, 'rain'],
#  [0.0, 11.1, 1.7, 3.0, 'sun'],
#  [0.0, 10.6, 2.8, 3.8, 'sun'],
#  [0.0, 11.1, 1.1, 1.8, 'sun'],
#  [0.0, 12.8, 4.4, 3.3, 'sun'],
#  [0.0, 18.9, 2.8, 2.2, 'sun'],
#  [4.1, 13.9, 6.7, 4.4, 'rain'],
#  [3.6, 11.1, 5.6, 2.4, 'rain'],
#  [0.3, 12.2, 6.7, 2.8, 'rain'],
#  [22.1, 11.7, 7.2, 3.9, 'rain'],
#  [14.0, 11.7, 7.2, 5.1, 'rain'],
#  [0.0, 11.1, 5.0, 5.1, 'sun'],
#  [0.0, 15.6, 2.2, 3.8, 'sun'],
#  [0.0, 14.4, 6.7, 2.8, 'sun'],
#  [0.0, 14.4, 5.6, 4.2, 'sun'],
#  [2.5, 13.3, 6.1, 3.9, 'rain'],
#  [0.0, 12.8, 6.1, 4.7, 'sun'],
#  [4.6, 11.7, 7.8, 4.3, 'rain'],
#  [0.0, 13.9, 8.3, 2.6, 'sun'],
#  [0.0, 21.1, 9.4, 2.5, 'sun'],
#  [4.6, 15.6, 8.3, 4.2, 'rain'],
#  [0.0, 14.4, 6.7, 2.9, 'sun'],
#  [0.0, 15.0, 6.7, 3.6, 'sun'],
#  [0.0, 17.2, 5.0, 2.8, 'sun'],
#  [0.0, 16.1, 7.8, 4.4, 'sun'],
#  [0.0, 20.6, 5.6, 3.1, 'sun'],
#  [0.0, 20.0, 5.6, 2.6, 'sun'],
#  [0.5, 14.4, 7.8, 4.0, 'rain'],
#  [10.9, 11.1, 8.9, 4.6, 'rain'],
#  [18.5, 11.7, 7.2, 4.7, 'rain'],
#  [0.0, 14.4, 5.6, 3.8, 'sun'],
#  [13.7, 11.7, 5.6, 4.7, 'rain'],
#  [0.0, 15.6, 5.6, 2.7, 'sun'],
#  [5.1, 17.2, 7.8, 2.5, 'rain'],
#  [14.2, 12.2, 5.0, 4.2, 'rain'],
#  [8.9, 11.7, 6.1, 5.0, 'rain'],
#  [12.4, 13.9, 6.1, 5.3, 'rain'],
#  [0.0, 14.4, 5.6, 2.3, 'sun'],
#  [3.3, 15.0, 5.6, 3.9, 'rain'],
#  [6.9, 11.1, 6.1, 5.8, 'rain'],
#  [0.0, 16.1, 4.4, 2.6, 'sun'],
#  [0.0, 25.0, 9.4, 2.3, 'sun'],
#  [0.0, 27.8, 9.4, 3.9, 'sun'],
#  [0.0, 29.4, 11.1, 3.0, 'sun'],
#  [0.0, 18.3, 10.6, 4.7, 'sun'],
#  [33.3, 15.0, 8.9, 3.4, 'rain'],
#  [16.0, 14.4, 8.9, 4.2, 'rain'],
#  [5.1, 15.6, 9.4, 3.8, 'rain'],
#  [0.0, 16.7, 8.3, 2.6, 'sun'],
#  [0.0, 18.3, 7.2, 1.7, 'sun'],
#  [13.7, 13.9, 9.4, 3.4, 'rain'],
#  [2.0, 13.3, 7.2, 5.6, 'rain'],
#  [0.5, 15.6, 7.2, 2.1, 'rain'],
#  [0.0, 18.9, 8.3, 1.7, 'sun'],
#  [0.0, 24.4, 9.4, 2.7, 'sun'],
#  [0.0, 26.7, 12.8, 3.8, 'sun'],
#  [0.0, 27.8, 13.3, 3.3, 'sun'],
#  [0.0, 26.7, 12.8, 3.0, 'sun'],
#  [0.0, 20.0, 11.7, 4.1, 'sun'],
#  [0.0, 20.0, 11.7, 3.2, 'sun'],
#  [0.0, 20.0, 10.6, 3.2, 'sun'],
#  [0.0, 21.1, 10.0, 2.2, 'sun'],
#  [0.0, 22.2, 10.0, 2.7, 'sun'],
#  [0.0, 20.0, 10.6, 1.7, 'sun'],
#  [0.0, 24.4, 11.7, 2.5, 'sun'],
#  [3.8, 20.0, 12.8, 4.0, 'rain'],
#  [0.0, 18.3, 11.1, 2.4, 'sun'],
#  [5.6, 15.0, 10.6, 1.4, 'rain'],
#  [0.0, 18.3, 11.1, 4.5, 'sun'],
#  [0.0, 20.0, 10.0, 2.5, 'sun'],
#  [0.0, 18.9, 10.0, 3.4, 'sun'],
#  [0.0, 18.9, 11.1, 4.3, 'sun'],
#  [0.0, 20.6, 8.9, 4.5, 'sun'],
#  [0.0, 23.3, 10.0, 2.2, 'sun'],
#  [0.0, 22.2, 10.6, 2.3, 'sun'],
#  [0.0, 23.3, 11.1, 2.4, 'sun'],
#  [0.0, 18.3, 11.1, 3.2, 'sun'],
#  [0.0, 19.4, 10.0, 2.6, 'sun'],
#  [0.0, 22.2, 10.0, 2.4, 'sun'],
#  [0.0, 25.0, 10.6, 3.2, 'sun'],
#  [0.0, 24.4, 13.3, 3.1, 'sun'],
#  [0.0, 23.3, 12.2, 2.1, 'sun'],
#  [0.0, 21.1, 13.3, 3.6, 'sun'],
#  [0.0, 20.0, 12.2, 2.9, 'sun'],
#  [0.0, 23.9, 11.1, 2.7, 'sun'],
#  [1.8, 21.7, 12.2, 4.0, 'rain'],
#  [6.4, 15.6, 11.1, 5.0, 'rain'],
#  [0.0, 17.8, 11.7, 3.2, 'sun'],
#  [0.5, 18.3, 10.0, 3.6, 'rain'],
#  [3.6, 17.8, 8.9, 2.4, 'rain'],
#  [1.3, 17.8, 10.0, 3.0, 'rain'],
#  [0.0, 18.9, 11.1, 2.7, 'sun'],
#  [0.8, 25.6, 11.7, 3.7, 'rain'],
#  [0.3, 20.0, 10.0, 3.4, 'rain'],
#  [0.0, 22.2, 10.6, 3.6, 'sun'],
#  [0.0, 25.0, 11.1, 2.7, 'sun'],
#  [0.0, 25.0, 13.3, 2.5, 'sun'],
#  [0.0, 24.4, 14.4, 2.5, 'sun'],
#  [0.0, 26.1, 13.9, 2.4, 'sun'],
#  [0.0, 21.1, 14.4, 4.1, 'sun'],
#  [1.8, 21.1, 13.9, 4.5, 'rain'],
#  [2.3, 20.0, 13.3, 4.3, 'rain'],
#  [0.0, 20.6, 12.8, 3.2, 'sun'],
#  [0.0, 25.6, 12.8, 4.4, 'sun'],
#  [0.0, 34.4, 15.6, 3.5, 'sun'],
#  [0.0, 27.2, 14.4, 3.6, 'sun'],
#  [0.0, 21.7, 13.9, 3.1, 'sun'],
#  [0.0, 23.9, 13.9, 3.6, 'sun'],
#  [0.0, 24.4, 13.3, 2.2, 'fog'],
#  [0.0, 28.9, 15.0, 3.0, 'sun'],
#  [0.0, 27.2, 17.8, 4.1, 'fog'],
#  [0.0, 30.0, 15.6, 3.5, 'sun'],
#  [0.0, 26.7, 13.9, 2.3, 'sun'],
#  [0.0, 28.9, 12.8, 2.2, 'fog'],
#  [0.0, 31.1, 15.0, 2.2, 'sun'],
#  [0.0, 32.2, 16.7, 2.2, 'sun'],
#  [0.0, 29.4, 15.0, 2.6, 'sun'],
#  [0.0, 27.8, 15.0, 2.8, 'sun'],
#  [0.0, 31.1, 13.9, 2.3, 'sun'],
#  [0.0, 31.1, 14.4, 2.4, 'sun'],
#  [0.0, 26.7, 13.9, 3.7, 'sun'],
#  [0.0, 23.9, 11.7, 2.8, 'sun'],
#  [0.0, 25.6, 15.0, 5.4, 'fog'],
#  [0.0, 19.4, 14.4, 2.8, 'sun'],
#  [0.0, 23.9, 13.3, 2.2, 'sun'],
#  [0.3, 21.1, 13.3, 1.1, 'rain'],
#  [19.3, 18.9, 13.3, 3.3, 'rain'],
#  [0.0, 20.6, 12.8, 4.7, 'sun'],
#  [0.0, 22.8, 12.2, 2.7, 'sun'],
#  [0.0, 26.1, 13.3, 3.6, 'sun'],
#  [0.0, 28.3, 15.0, 4.1, 'sun'],
#  [0.0, 30.6, 15.0, 3.7, 'sun'],
#  [0.0, 30.0, 15.6, 2.8, 'sun'],
#  [0.0, 29.4, 14.4, 3.4, 'sun'],
#  [0.0, 30.6, 17.8, 4.1, 'sun'],
#  [0.0, 28.9, 15.0, 3.3, 'sun'],
#  [0.5, 29.4, 15.6, 1.7, 'rain'],
#  [0.0, 31.7, 14.4, 2.6, 'sun'],
#  [0.0, 32.8, 16.1, 2.6, 'sun'],
#  [0.0, 25.0, 13.9, 2.7, 'sun'],
#  [0.0, 26.1, 15.0, 2.2, 'fog'],
#  [0.0, 25.6, 13.3, 2.4, 'fog'],
#  [0.0, 25.6, 13.3, 2.9, 'sun'],
#  [0.0, 27.2, 15.6, 4.1, 'sun'],
#  [0.0, 30.6, 13.9, 3.4, 'sun'],
#  [0.5, 35.6, 17.8, 2.6, 'rain'],
#  [12.7, 27.2, 17.2, 3.1, 'rain'],
#  [21.6, 23.3, 15.0, 2.7, 'rain'],
#  [0.0, 21.1, 17.2, 0.6, 'sun'],
#  [1.0, 24.4, 16.7, 1.5, 'rain'],
#  [0.0, 25.6, 15.6, 2.2, 'sun'],
#  [0.0, 27.8, 15.0, 2.8, 'sun'],
#  [0.0, 29.4, 15.6, 3.3, 'sun'],
#  [0.0, 27.2, 15.6, 2.4, 'sun'],
#  [0.0, 21.7, 13.9, 3.6, 'sun'],
#  [0.0, 21.1, 11.1, 1.7, 'sun'],
#  [0.0, 23.9, 13.3, 2.9, 'sun'],
#  [0.0, 27.8, 13.9, 2.0, 'sun'],
#  [0.0, 25.0, 13.3, 2.3, 'sun'],
#  [0.0, 28.9, 14.4, 2.0, 'sun'],
#  [0.0, 31.1, 15.6, 1.8, 'sun'],
#  [0.0, 28.9, 16.1, 1.6, 'sun'],
#  [0.0, 23.3, 14.4, 2.3, 'sun'],
#  [0.0, 22.8, 15.0, 3.4, 'sun'],
#  [8.4, 17.8, 15.0, 2.2, 'rain'],
#  [1.3, 21.1, 13.9, 1.9, 'rain'],
#  [0.0, 23.3, 12.8, 2.5, 'sun'],
#  [3.0, 20.0, 13.9, 4.3, 'rain'],
#  [0.0, 20.6, 12.8, 2.7, 'sun'],
#  [0.0, 23.9, 11.1, 3.1, 'fog'],
#  [0.0, 27.8, 13.9, 6.5, 'fog'],
#  [0.0, 32.2, 15.0, 2.9, 'sun'],
#  [0.0, 28.3, 13.3, 2.1, 'sun'],
#  [0.0, 21.1, 13.3, 2.8, 'sun'],
#  [0.0, 21.7, 13.3, 2.3, 'sun'],
#  [0.0, 22.2, 12.2, 3.9, 'sun'],
#  [0.0, 24.4, 12.8, 5.3, 'sun'],
#  [0.0, 24.4, 12.8, 5.9, 'sun'],
#  [0.0, 28.3, 10.0, 4.2, 'sun'],
#  [0.0, 30.0, 11.7, 1.8, 'sun'],
#  [0.0, 30.6, 12.2, 1.2, 'sun'],
#  [0.0, 22.2, 13.9, 2.8, 'sun'],
#  [0.5, 22.8, 14.4, 2.3, 'rain'],
#  [0.3, 19.4, 15.0, 3.1, 'rain'],
#  [0.0, 23.9, 16.1, 2.8, 'sun'],
#  [0.0, 24.4, 14.4, 4.4, 'fog'],
#  [0.0, 26.1, 12.8, 3.0, 'sun'],
#  [0.3, 22.2, 15.0, 2.1, 'rain'],
#  [18.3, 18.9, 14.4, 2.5, 'rain'],
#  [20.3, 18.9, 14.4, 2.7, 'rain'],
#  [4.3, 21.7, 14.4, 2.5, 'rain'],
#  [8.9, 20.0, 13.9, 3.3, 'rain'],
#  ...]

# %%
#Test label_count
#counts=label_count(training_data)
#counts

# %%
# Test the partition_criteria
#pc = partition_criteria(0, 'Rainfall')
#pc

# %%
#Test label_count
#counts=label_count(training_data)
#counts

# %%
# Test using a sample row from training_data
#sample = training_data[11]
#print(sample)
#pc.compare(sample)

# %%
# Test get_split
#passed_rows, failed_rows = get_split(training_data, partition_criteria(0, 'Rainfall'))
#passed_rows

# %%
#######
# Test gini_impurity for training data
# Calculate the impurity of training data.
#current_impurity = gini_impurity(training_data)
#current_impurity

# %%
# Information gain by partioning on 'Rainfall'?
#p_rows, f_rows = get_split(training_data, partition_criteria(0, 'Rainfall'))
#info_gain(p_rows, f_rows, current_impurity)

# %%
# Information gain by partioning on 'Overcast'
#p_rows, f_rows = get_split(training_data, partition_criteria(0,'Overcast'))
#info_gain(p_rows, f_rows, current_impurity)

# %%
# More information is gained using 'Overcast' (0.15), than 'Rainfall' (0.0042).
# Why? Look at the different splits that result, and see which one
# looks more 'unmixed' to you.
#p_rows, f_rows = get_split(training_data, partition_criteria(0,'Overcast'))

# Here, the true_rows contain only 'Yes'.
#p_rows

# %%
# And the false rows contain two types of Decisions (Yes and No).Which means more impurity
#f_rows

# %%
# On the other hand, partitioning by Rainfall doesn't help so much.(No pure groups)
#passed_rows, failed_rows = get_split(training_data, partition_criteria(0,'Rainfall'))

# We've isolated one apple in the true rows.
#passed_rows

# %%
# But, the false-rows are badly mixed up.
#failed_rows
#######

# %%
# Test find_best_criteria on training_data .
#best_gain, best_criteria = find_best_split(training_data)
#best_criteria

# %% [markdown]
# #### Build a Tree using Training Data

# %%
my_tree = build_tree(training_data)

# %% [markdown]
# ##### Print the Tree

# %%
print_tree(my_tree)
# Out:
# precipitation >= 0.3?
# --> True:
#   temp_min >= 1.1?
#   --> True:
#     temp_min >= 3.3?
#     --> True:
#       precipitation >= 23.9?
#       --> True:
#         precipitation >= 25.4?
#         --> True:
#           Decision : {'rain': '100.0%'}
#         --> False:
#           Decision : {'snow': '100.0%'}
#       --> False:
#         Decision : {'rain': '100.0%'}
#     --> False:
#       wind >= 4.2?
#       --> True:
#         wind >= 4.3?
#         --> True:
#           precipitation >= 1.3?
#           --> True:
#             temp_max >= 8.3?
#             --> True:
#               temp_max >= 8.9?
#               --> True:
#                 wind >= 5.1?
#                 --> True:
#                   Decision : {'rain': '100.0%'}
#                 --> False:
#                   wind >= 4.9?
#                   --> True:
#                     Decision : {'snow': '100.0%'}
#                   --> False:
#                     Decision : {'rain': '100.0%'}
#               --> False:
#                 Decision : {'snow': '100.0%'}
#             --> False:
#               Decision : {'rain': '100.0%'}
#           --> False:
#             Decision : {'snow': '100.0%'}
#         --> False:
#           Decision : {'snow': '100.0%'}
#       --> False:
#         wind >= 2.1?
#         --> True:
#           Decision : {'rain': '100.0%'}
#         --> False:
#           temp_max >= 9.4?
#           --> True:
#             Decision : {'snow': '100.0%'}
#           --> False:
#             Decision : {'rain': '100.0%'}
#   --> False:
#     wind >= 4.6?
#     --> True:
#       Decision : {'snow': '100.0%'}
#     --> False:
#       temp_max >= 3.9?
#       --> True:
#         Decision : {'rain': '100.0%'}
#       --> False:
#         Decision : {'snow': '100.0%'}
# --> False:
#   temp_max >= 18.3?
#   --> True:
#     wind >= 1.5?
#     --> True:
#       wind >= 2.8?
#       --> True:
#         temp_min >= 6.1?
#         --> True:
#           temp_min >= 13.3?
#           --> True:
#             wind >= 5.4?
#             --> True:
#               temp_min >= 16.1?
#               --> True:
#                 Decision : {'sun': '100.0%'}
#               --> False:
#                 Decision : {'fog': '100.0%'}
#             --> False:
#               temp_max >= 19.4?
#               --> True:
#                 temp_max >= 25.0?
#                 --> True:
#                   temp_max >= 25.6?
#                   --> True:
#                     temp_min >= 13.9?
#                     --> True:
#                       temp_min >= 17.8?
#                       --> True:
#                         temp_max >= 31.1?
#                         --> True:
#                           Decision : {'sun': '100.0%'}
#                         --> False:
#                           Decision : {'fog': '100.0%'}
#                       --> False:
#                         temp_max >= 29.4?
#                         --> True:
#                           temp_max >= 30.0?
#                           --> True:
#                             wind >= 3.5?
#                             --> True:
#                               Decision : {'sun': '100.0%'}
#                             --> False:
#                               wind >= 3.4?
#                               --> True:
#                                 temp_min >= 15.0?
#                                 --> True:
#                                   Decision : {'fog': '100.0%'}
#                                 --> False:
#                                   Decision : {'sun': '100.0%'}
#                               --> False:
#                                 Decision : {'sun': '100.0%'}
#                           --> False:
#                             wind >= 3.3?
#                             --> True:
#                               Decision : {'sun': '100.0%'}
#                             --> False:
#                               Decision : {'drizzle': '100.0%'}
#                         --> False:
#                           Decision : {'sun': '100.0%'}
#                     --> False:
#                       temp_max >= 27.8?
#                       --> True:
#                         Decision : {'fog': '100.0%'}
#                       --> False:
#                         Decision : {'sun': '100.0%'}
#                   --> False:
#                     wind >= 3.6?
#                     --> True:
#                       wind >= 3.7?
#                       --> True:
#                         Decision : {'sun': '100.0%'}
#                       --> False:
#                         Decision : {'fog': '100.0%'}
#                     --> False:
#                       Decision : {'sun': '100.0%'}
#                 --> False:
#                   temp_min >= 14.4?
#                   --> True:
#                     temp_max >= 24.4?
#                     --> True:
#                       Decision : {'drizzle': '100.0%'}
#                     --> False:
#                       wind >= 3.4?
#                       --> True:
#                         Decision : {'sun': '100.0%'}
#                       --> False:
#                         wind >= 3.0?
#                         --> True:
#                           temp_min >= 16.7?
#                           --> True:
#                             Decision : {'sun': '100.0%'}
#                           --> False:
#                             Decision : {'drizzle': '100.0%'}
#                         --> False:
#                           Decision : {'sun': '100.0%'}
#                   --> False:
#                     temp_min >= 13.9?
#                     --> True:
#                       Decision : {'sun': '100.0%'}
#                     --> False:
#                       temp_max >= 23.3?
#                       --> True:
#                         wind >= 3.0?
#                         --> True:
#                           Decision : {'rain': '100.0%'}
#                         --> False:
#                           Decision : {'sun': '100.0%'}
#                       --> False:
#                         Decision : {'sun': '100.0%'}
#               --> False:
#                 Decision : {'rain': '100.0%'}
#           --> False:
#             wind >= 3.5?
#             --> True:
#               Decision : {'sun': '100.0%'}
#             --> False:
#               wind >= 3.4?
#               --> True:
#                 temp_max >= 23.9?
#                 --> True:
#                   Decision : {'sun': '100.0%'}
#                 --> False:
#                   temp_max >= 21.1?
#                   --> True:
#                     temp_min >= 12.2?
#                     --> True:
#                       Decision : {'sun': '50.0%', 'fog': '50.0%'}
#                     --> False:
#                       Decision : {'fog': '100.0%'}
#                   --> False:
#                     Decision : {'sun': '100.0%'}
#               --> False:
#                 temp_min >= 9.4?
#                 --> True:
#                   Decision : {'sun': '100.0%'}
#                 --> False:
#                   temp_min >= 8.9?
#                   --> True:
#                     Decision : {'rain': '100.0%'}
#                   --> False:
#                     Decision : {'sun': '100.0%'}
#         --> False:
#           wind >= 4.4?
#           --> True:
#             Decision : {'drizzle': '100.0%'}
#           --> False:
#             Decision : {'sun': '100.0%'}
#       --> False:
#         temp_max >= 23.9?
#         --> True:
#           wind >= 2.4?
#           --> True:
#             temp_max >= 27.2?
#             --> True:
#               temp_max >= 28.9?
#               --> True:
#                 Decision : {'sun': '100.0%'}
#               --> False:
#                 temp_max >= 28.3?
#                 --> True:
#                   temp_min >= 15.6?
#                   --> True:
#                     Decision : {'rain': '100.0%'}
#                   --> False:
#                     Decision : {'sun': '100.0%'}
#                 --> False:
#                   Decision : {'sun': '100.0%'}
#             --> False:
#               wind >= 2.5?
#               --> True:
#                 temp_max >= 25.6?
#                 --> True:
#                   temp_min >= 14.4?
#                   --> True:
#                     Decision : {'fog': '100.0%'}
#                   --> False:
#                     wind >= 2.7?
#                     --> True:
#                       Decision : {'drizzle': '100.0%'}
#                     --> False:
#                       temp_min >= 12.8?
#                       --> True:
#                         Decision : {'sun': '100.0%'}
#                       --> False:
#                         Decision : {'sun': '50.0%', 'drizzle': '50.0%'}
#                 --> False:
#                   Decision : {'sun': '100.0%'}
#               --> False:
#                 temp_min >= 13.3?
#                 --> True:
#                   temp_max >= 25.0?
#                   --> True:
#                     Decision : {'fog': '100.0%'}
#                   --> False:
#                     Decision : {'sun': '100.0%'}
#                 --> False:
#                   Decision : {'sun': '100.0%'}
#           --> False:
#             temp_max >= 24.4?
#             --> True:
#               temp_max >= 31.7?
#               --> True:
#                 temp_max >= 32.2?
#                 --> True:
#                   Decision : {'sun': '100.0%'}
#                 --> False:
#                   Decision : {'drizzle': '100.0%'}
#               --> False:
#                 wind >= 1.9?
#                 --> True:
#                   Decision : {'sun': '100.0%'}
#                 --> False:
#                   wind >= 1.8?
#                   --> True:
#                     temp_min >= 13.9?
#                     --> True:
#                       temp_min >= 15.0?
#                       --> True:
#                         Decision : {'sun': '100.0%'}
#                       --> False:
#                         Decision : {'drizzle': '100.0%'}
#                     --> False:
#                       Decision : {'sun': '100.0%'}
#                   --> False:
#                     Decision : {'sun': '100.0%'}
#             --> False:
#               temp_min >= 13.3?
#               --> True:
#                 Decision : {'sun': '50.0%', 'drizzle': '50.0%'}
#               --> False:
#                 Decision : {'sun': '100.0%'}
#         --> False:
#           temp_min >= 10.6?
#           --> True:
#             temp_max >= 22.8?
#             --> True:
#               wind >= 2.0?
#               --> True:
#                 Decision : {'sun': '100.0%'}
#               --> False:
#                 Decision : {'fog': '100.0%'}
#             --> False:
#               temp_min >= 11.1?
#               --> True:
#                 temp_max >= 21.7?
#                 --> True:
#                   wind >= 2.2?
#                   --> True:
#                     wind >= 2.5?
#                     --> True:
#                       wind >= 2.7?
#                       --> True:
#                         Decision : {'fog': '100.0%'}
#                       --> False:
#                         temp_min >= 11.7?
#                         --> True:
#                           Decision : {'rain': '100.0%'}
#                         --> False:
#                           Decision : {'fog': '100.0%'}
#                     --> False:
#                       wind >= 2.3?
#                       --> True:
#                         Decision : {'sun': '100.0%'}
#                       --> False:
#                         Decision : {'fog': '100.0%'}
#                   --> False:
#                     Decision : {'drizzle': '100.0%'}
#                 --> False:
#                   temp_min >= 12.2?
#                   --> True:
#                     temp_min >= 12.8?
#                     --> True:
#                       temp_min >= 14.4?
#                       --> True:
#                         wind >= 2.6?
#                         --> True:
#                           Decision : {'drizzle': '100.0%'}
#                         --> False:
#                           wind >= 2.4?
#                           --> True:
#                             Decision : {'fog': '100.0%'}
#                           --> False:
#                             Decision : {'sun': '100.0%'}
#                       --> False:
#                         Decision : {'sun': '100.0%'}
#                     --> False:
#                       wind >= 2.3?
#                       --> True:
#                         Decision : {'rain': '100.0%'}
#                       --> False:
#                         Decision : {'fog': '100.0%'}
#                   --> False:
#                     Decision : {'sun': '100.0%'}
#               --> False:
#                 Decision : {'sun': '100.0%'}
#           --> False:
#             temp_max >= 23.3?
#             --> True:
#               Decision : {'rain': '100.0%'}
#             --> False:
#               temp_max >= 20.6?
#               --> True:
#                 Decision : {'sun': '100.0%'}
#               --> False:
#                 temp_max >= 19.4?
#                 --> True:
#                   wind >= 2.0?
#                   --> True:
#                     Decision : {'drizzle': '100.0%'}
#                   --> False:
#                     wind >= 1.8?
#                     --> True:
#                       Decision : {'sun': '100.0%'}
#                     --> False:
#                       Decision : {'drizzle': '100.0%'}
#                 --> False:
#                   Decision : {'sun': '100.0%'}
#     --> False:
#       temp_max >= 20.0?
#       --> True:
#         temp_min >= 12.2?
#         --> True:
#           wind >= 1.2?
#           --> True:
#             Decision : {'sun': '100.0%'}
#           --> False:
#             wind >= 1.1?
#             --> True:
#               Decision : {'rain': '100.0%'}
#             --> False:
#               Decision : {'sun': '100.0%'}
#         --> False:
#           temp_min >= 9.4?
#           --> True:
#             temp_max >= 27.8?
#             --> True:
#               Decision : {'sun': '100.0%'}
#             --> False:
#               Decision : {'fog': '100.0%'}
#           --> False:
#             Decision : {'sun': '100.0%'}
#       --> False:
#         Decision : {'fog': '100.0%'}
#   --> False:
#     wind >= 2.8?
#     --> True:
#       temp_min >= 0.6?
#       --> True:
#         temp_max >= 12.2?
#         --> True:
#           temp_min >= 6.7?
#           --> True:
#             wind >= 3.4?
#             --> True:
#               temp_min >= 7.2?
#               --> True:
#                 wind >= 4.7?
#                 --> True:
#                   temp_min >= 10.0?
#                   --> True:
#                     Decision : {'fog': '100.0%'}
#                   --> False:
#                     wind >= 5.1?
#                     --> True:
#                       Decision : {'sun': '100.0%'}
#                     --> False:
#                       temp_min >= 8.3?
#                       --> True:
#                         Decision : {'rain': '100.0%'}
#                       --> False:
#                         Decision : {'sun': '100.0%'}
#                 --> False:
#                   Decision : {'sun': '100.0%'}
#               --> False:
#                 wind >= 5.9?
#                 --> True:
#                   Decision : {'sun': '100.0%'}
#                 --> False:
#                   Decision : {'rain': '100.0%'}
#             --> False:
#               temp_min >= 9.4?
#               --> True:
#                 Decision : {'sun': '100.0%'}
#               --> False:
#                 temp_max >= 15.6?
#                 --> True:
#                   Decision : {'rain': '100.0%'}
#                 --> False:
#                   temp_min >= 8.9?
#                   --> True:
#                     Decision : {'fog': '100.0%'}
#                   --> False:
#                     Decision : {'sun': '100.0%'}
#           --> False:
#             temp_max >= 16.1?
#             --> True:
#               Decision : {'sun': '100.0%'}
#             --> False:
#               temp_max >= 15.0?
#               --> True:
#                 Decision : {'drizzle': '100.0%'}
#               --> False:
#                 wind >= 4.7?
#                 --> True:
#                   wind >= 4.8?
#                   --> True:
#                     Decision : {'sun': '100.0%'}
#                   --> False:
#                     Decision : {'drizzle': '100.0%'}
#                 --> False:
#                   Decision : {'sun': '100.0%'}
#         --> False:
#           wind >= 3.7?
#           --> True:
#             wind >= 5.5?
#             --> True:
#               wind >= 6.1?
#               --> True:
#                 temp_max >= 7.8?
#                 --> True:
#                   Decision : {'sun': '100.0%'}
#                 --> False:
#                   Decision : {'rain': '100.0%'}
#               --> False:
#                 Decision : {'rain': '100.0%'}
#             --> False:
#               wind >= 5.2?
#               --> True:
#                 Decision : {'fog': '100.0%'}
#               --> False:
#                 temp_max >= 7.2?
#                 --> True:
#                   wind >= 4.7?
#                   --> True:
#                     Decision : {'sun': '100.0%'}
#                   --> False:
#                     wind >= 4.5?
#                     --> True:
#                       Decision : {'fog': '100.0%'}
#                     --> False:
#                       wind >= 4.2?
#                       --> True:
#                         Decision : {'sun': '100.0%'}
#                       --> False:
#                         wind >= 4.1?
#                         --> True:
#                           Decision : {'fog': '100.0%'}
#                         --> False:
#                           Decision : {'sun': '100.0%'}
#                 --> False:
#                   Decision : {'fog': '100.0%'}
#           --> False:
#             temp_max >= 10.6?
#             --> True:
#               temp_min >= 5.6?
#               --> True:
#                 Decision : {'rain': '100.0%'}
#               --> False:
#                 Decision : {'sun': '100.0%'}
#             --> False:
#               Decision : {'rain': '100.0%'}
#       --> False:
#         Decision : {'sun': '100.0%'}
#     --> False:
#       temp_min >= 3.9?
#       --> True:
#         temp_max >= 10.0?
#         --> True:
#           temp_min >= 5.6?
#           --> True:
#             temp_min >= 6.7?
#             --> True:
#               temp_max >= 12.8?
#               --> True:
#                 temp_min >= 7.2?
#                 --> True:
#                   wind >= 1.2?
#                   --> True:
#                     temp_max >= 16.7?
#                     --> True:
#                       wind >= 2.6?
#                       --> True:
#                         Decision : {'sun': '100.0%'}
#                       --> False:
#                         temp_max >= 17.2?
#                         --> True:
#                           Decision : {'fog': '100.0%'}
#                         --> False:
#                           Decision : {'sun': '100.0%'}
#                     --> False:
#                       wind >= 2.6?
#                       --> True:
#                         Decision : {'fog': '100.0%'}
#                       --> False:
#                         temp_min >= 7.8?
#                         --> True:
#                           wind >= 1.7?
#                           --> True:
#                             wind >= 1.8?
#                             --> True:
#                               wind >= 2.5?
#                               --> True:
#                                 temp_min >= 10.0?
#                                 --> True:
#                                   Decision : {'fog': '100.0%'}
#                                 --> False:
#                                   Decision : {'drizzle': '100.0%'}
#                               --> False:
#                                 Decision : {'sun': '100.0%'}
#                             --> False:
#                               Decision : {'fog': '100.0%'}
#                           --> False:
#                             Decision : {'drizzle': '100.0%'}
#                         --> False:
#                           Decision : {'sun': '100.0%'}
#                   --> False:
#                     Decision : {'fog': '100.0%'}
#                 --> False:
#                   Decision : {'fog': '100.0%'}
#               --> False:
#                 Decision : {'sun': '100.0%'}
#             --> False:
#               temp_max >= 13.3?
#               --> True:
#                 Decision : {'sun': '100.0%'}
#               --> False:
#                 wind >= 1.0?
#                 --> True:
#                   Decision : {'fog': '100.0%'}
#                 --> False:
#                   Decision : {'sun': '100.0%'}
#           --> False:
#             temp_max >= 12.8?
#             --> True:
#               temp_min >= 5.0?
#               --> True:
#                 Decision : {'drizzle': '100.0%'}
#               --> False:
#                 wind >= 2.7?
#                 --> True:
#                   Decision : {'fog': '100.0%'}
#                 --> False:
#                   temp_max >= 15.6?
#                   --> True:
#                     Decision : {'sun': '100.0%'}
#                   --> False:
#                     temp_max >= 13.9?
#                     --> True:
#                       Decision : {'fog': '100.0%'}
#                     --> False:
#                       wind >= 2.3?
#                       --> True:
#                         Decision : {'sun': '100.0%'}
#                       --> False:
#                         Decision : {'fog': '100.0%'}
#             --> False:
#               temp_min >= 4.4?
#               --> True:
#                 Decision : {'fog': '100.0%'}
#               --> False:
#                 wind >= 1.6?
#                 --> True:
#                   Decision : {'drizzle': '100.0%'}
#                 --> False:
#                   Decision : {'fog': '100.0%'}
#         --> False:
#           wind >= 2.7?
#           --> True:
#             Decision : {'sun': '100.0%'}
#           --> False:
#             temp_max >= 8.3?
#             --> True:
#               Decision : {'rain': '100.0%'}
#             --> False:
#               Decision : {'fog': '100.0%'}
#       --> False:
#         temp_max >= 10.0?
#         --> True:
#           wind >= 2.7?
#           --> True:
#             Decision : {'rain': '100.0%'}
#           --> False:
#             wind >= 1.4?
#             --> True:
#               Decision : {'sun': '100.0%'}
#             --> False:
#               temp_min >= 2.8?
#               --> True:
#                 Decision : {'sun': '100.0%'}
#               --> False:
#                 Decision : {'fog': '100.0%'}
#         --> False:
#           wind >= 2.5?
#           --> True:
#             temp_min >= 0.6?
#             --> True:
#               wind >= 2.7?
#               --> True:
#                 Decision : {'fog': '100.0%'}
#               --> False:
#                 temp_min >= 3.3?
#                 --> True:
#                   Decision : {'sun': '100.0%'}
#                 --> False:
#                   temp_max >= 8.3?
#                   --> True:
#                     Decision : {'sun': '100.0%'}
#                   --> False:
#                     Decision : {'fog': '100.0%'}
#             --> False:
#               Decision : {'sun': '100.0%'}
#           --> False:
#             wind >= 1.8?
#             --> True:
#               temp_min >= 3.3?
#               --> True:
#                 wind >= 2.0?
#                 --> True:
#                   Decision : {'sun': '100.0%'}
#                 --> False:
#                   Decision : {'fog': '100.0%'}
#               --> False:
#                 wind >= 2.3?
#                 --> True:
#                   wind >= 2.4?
#                   --> True:
#                     Decision : {'drizzle': '100.0%'}
#                   --> False:
#                     Decision : {'sun': '100.0%'}
#                 --> False:
#                   temp_min >= -1.1?
#                   --> True:
#                     temp_max >= 8.9?
#                     --> True:
#                       temp_min >= 1.7?
#                       --> True:
#                         Decision : {'drizzle': '100.0%'}
#                       --> False:
#                         Decision : {'rain': '100.0%'}
#                     --> False:
#                       Decision : {'drizzle': '100.0%'}
#                   --> False:
#                     wind >= 2.0?
#                     --> True:
#                       Decision : {'sun': '100.0%'}
#                     --> False:
#                       temp_min >= -1.7?
#                       --> True:
#                         Decision : {'sun': '100.0%'}
#                       --> False:
#                         Decision : {'drizzle': '100.0%'}
#             --> False:
#               temp_max >= 7.2?
#               --> True:
#                 wind >= 1.5?
#                 --> True:
#                   wind >= 1.7?
#                   --> True:
#                     Decision : {'sun': '100.0%'}
#                   --> False:
#                     Decision : {'rain': '100.0%'}
#                 --> False:
#                   Decision : {'sun': '100.0%'}
#               --> False:
#                 temp_min >= 1.7?
#                 --> True:
#                   Decision : {'fog': '100.0%'}
#                 --> False:
#                   temp_max >= 2.2?
#                   --> True:
#                     wind >= 0.8?
#                     --> True:
#                       temp_max >= 6.7?
#                       --> True:
#                         Decision : {'drizzle': '100.0%'}
#                       --> False:
#                         Decision : {'sun': '100.0%'}
#                     --> False:
#                       Decision : {'drizzle': '100.0%'}
#                   --> False:
#                     Decision : {'fog': '100.0%'}

# %%
## Test Classify :
#classify(training_data[0], my_tree)

# %%
## Test print_leaf
#print_leaf(classify(training_data[0], my_tree))

# %% [markdown]
# #### Test the DT for testing_data

# %%
for row in testing_data:
    print (f"Actual: {row[-1]}. Prediction_with_Probability: { print_leaf(classify(row, my_tree)) }")
# Out:
# Actual: drizzle. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'drizzle': '100%'}
# Actual: rain. Prediction_with_Probability: {'fog': '100%'}
# Actual: sun. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: fog. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: fog. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'fog': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '50%', 'drizzle': '50%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: fog. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: fog. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'fog': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: fog. Prediction_with_Probability: {'drizzle': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: drizzle. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'fog': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'drizzle': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'fog': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: snow. Prediction_with_Probability: {'snow': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'drizzle': '100%'}
# Actual: fog. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: fog. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'drizzle': '100%'}
# Actual: sun. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'drizzle': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'fog': '100%'}
# Actual: sun. Prediction_with_Probability: {'fog': '100%'}
# Actual: fog. Prediction_with_Probability: {'sun': '100%'}
# Actual: snow. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: drizzle. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'drizzle': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'fog': '100%'}
# Actual: sun. Prediction_with_Probability: {'drizzle': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'sun': '100%'}
# Actual: fog. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'fog': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: fog. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'drizzle': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'fog': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: fog. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: drizzle. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: fog. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: fog. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'rain': '100%'}
# Actual: fog. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: fog. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'drizzle': '100%'}
# Actual: fog. Prediction_with_Probability: {'fog': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: fog. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: fog. Prediction_with_Probability: {'fog': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: drizzle. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: fog. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: fog. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: fog. Prediction_with_Probability: {'fog': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'drizzle': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: snow. Prediction_with_Probability: {'rain': '100%'}
# Actual: snow. Prediction_with_Probability: {'rain': '100%'}
# Actual: drizzle. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: fog. Prediction_with_Probability: {'drizzle': '100%'}
# Actual: sun. Prediction_with_Probability: {'rain': '100%'}
# Actual: drizzle. Prediction_with_Probability: {'sun': '100%'}
# Actual: snow. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'drizzle': '100%'}
# Actual: drizzle. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: fog. Prediction_with_Probability: {'fog': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: fog. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'rain': '100%'}
# Actual: fog. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'fog': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'drizzle': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: drizzle. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'fog': '100%'}
# Actual: fog. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'fog': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: fog. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: drizzle. Prediction_with_Probability: {'sun': '100%'}
# Actual: drizzle. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'drizzle': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'drizzle': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: fog. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: fog. Prediction_with_Probability: {'fog': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: snow. Prediction_with_Probability: {'snow': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'drizzle': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: drizzle. Prediction_with_Probability: {'sun': '100%'}
# Actual: drizzle. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'fog': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'sun': '100%'}
# Actual: fog. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: fog. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: snow. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '50%', 'drizzle': '50%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '50%', 'drizzle': '50%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'drizzle': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'drizzle': '100%'}
# Actual: fog. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'fog': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: drizzle. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: fog. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'fog': '100%'}
# Actual: snow. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '50%', 'drizzle': '50%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'fog': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'fog': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: fog. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'fog': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'fog': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: fog. Prediction_with_Probability: {'drizzle': '100%'}
# Actual: rain. Prediction_with_Probability: {'snow': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'drizzle': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'snow': '100%'}
# Actual: drizzle. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'drizzle': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'fog': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: snow. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: fog. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'fog': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: fog. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: snow. Prediction_with_Probability: {'snow': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'drizzle': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'fog': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'fog': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'drizzle': '100%'}
# Actual: sun. Prediction_with_Probability: {'drizzle': '100%'}
# Actual: sun. Prediction_with_Probability: {'fog': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'drizzle': '100%'}
# Actual: drizzle. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'fog': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: fog. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: fog. Prediction_with_Probability: {'fog': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: drizzle. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: fog. Prediction_with_Probability: {'drizzle': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'fog': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: drizzle. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'fog': '100%'}
# Actual: sun. Prediction_with_Probability: {'drizzle': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'drizzle': '100%'}
# Actual: fog. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: drizzle. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'fog': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'snow': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: snow. Prediction_with_Probability: {'snow': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'drizzle': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: drizzle. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: sun. Prediction_with_Probability: {'sun': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}
# Actual: rain. Prediction_with_Probability: {'rain': '100%'}

# %%
accuracy(testing_data)
# Out:
# 98.26314050626938
